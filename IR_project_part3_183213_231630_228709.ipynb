# %% [markdown]
# # Information Retrieval and Web Analytics

# %% [markdown]
# ## PROJECT PART 1: Text Processing

# %% [markdown]
# Group Members:
#
# *   Berta Alòs (228709)
# *   Maria Cerezo (183213)
# *   Paula Vilà (231630)

# %% [markdown]
# Load packages

# %%
from collections import defaultdict
from array import array
import nltk
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
import json 
from numpy import linalg as la
import pandas as pd 
import re
from operator import itemgetter
import unicodedata
import time
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Data preparation and Text processing
# The dataset is stored in the JSON file. It contains 4000 Hurricane Ian tweets.

# %%
#reading json file and transforming it into pandas dataframe
tw_data = pd.read_json('tw_hurricane_data.json',lines=True)

#reading the csv file and transforming it into pandas dataframe
map_data = pd.read_csv('tweet_document_ids_map.csv',
                    sep='::', 
                    encoding='latin-1',
                    engine='python',
                    names=['docs_ids'])

tw_data = pd.DataFrame(tw_data)

# %%
#creating a new dataframe with the desired columns extracted from tw_data dataframe 
tw_fields = pd.DataFrame()
tw_fields['hashtags']=None
tw_fields['name']=None
tw_fields['full_text']=None
tw_fields['created_at']=None
tw_fields['favorite_count']=None
tw_fields['retweet_count']=None
tw_fields['url']=None

#creating a column with hashtag information obtained from entities column
tw_fields['hashtags'] = tw_data['entities'].apply(lambda x: x.get('hashtags'))

#creating a column with username information obtained from user column
tw_fields['name'] = tw_data['user'].apply(lambda x: x.get('name'))

#creating a column with url information obtained from entities column
for i in tw_data.index:
  tw_fields['url'][i]=tw_data['entities'][i]['media'][0]['url'] if(tw_data['entities'][i].get('media') is not None) else {}

#creating a column with the full_text information of the tw_data dataframe
tw_fields['full_text']=tw_data['full_text']

#creating a column with the created_at information of the tw_data dataframe
tw_fields['created_at']=tw_data['created_at']

#creating a column with the favorite_count information of the tw_data dataframe
tw_fields['favorite_count']=tw_data['favorite_count']

#creating a column with the retweet_count information of the tw_data dataframe
tw_fields['retweet_count']=tw_data['retweet_count']

# %%
#creating a new dataset containing the required columns, with it's specified column names
tw_fields = pd.DataFrame({'Tweet' : tw_fields['full_text'],'Username' : tw_fields['name'],  'Date' : tw_fields['created_at'],'Hashtags' : tw_fields['hashtags'], 'Likes' : tw_fields['favorite_count'], 'Retweets' : tw_fields['retweet_count'], 'Url' : tw_fields['url']})

# %%
#Function to preprocess data
def build_terms(line):
    """
    Preprocess the text removing stop words, stemming, transforming in 
    lowercase, removing URLs and emojis, removing everything it is not a digit 
    nor number and return the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    line=re.sub(r'[\W_]+', ' ', line) #BONUS: Removing anything is not a letter or digit
    line = line.lower() 
    line = line.split()  # Tokenize the text to get a list of terms
    line = [x for x in line if x not in stop_words]  # eliminate the stopwords
    line = [stemmer.stem(word) for word in line] # perform stemming (HINT: use List Comprehension)
    line = [l for l in line if "http" not in l ] #BONUS: Removing the URLs from the line
    line = [emojis_out(l) for l in line ] ##BONUS: removing the emojis from the line
    return line

# %%
#Function to get rid of emojis
def emojis_out (s):
    """Preprocess the text removing stop emojis from of the string
    
    Arguments:
    s -- string (word) to be processed
    
    Returns: 
    word-- string equal to "" if it's  an emoji and "s" otherwise. 
    """
    emoji_pattern = re.compile("["  
        u"\U0001F300-\U0001F5FF"  # removing symbols & pictographs  
                           "]+", flags=re.UNICODE)
       
    word = emoji_pattern.sub(r'', s)
    return word

# %%
#preprocessing the Tweet and Username information
tw_fields['preprocessed_tweet']=None
for i in tw_fields.index: 
    tw_fields['preprocessed_tweet'][i] = build_terms(tw_fields['Tweet'][i]) 
    tw_fields['Username'][i]=emojis_out(tw_fields['Username'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#merging the tw_fields & map_data dataframes into a single dataframe named final_dataset
final_dataset=pd.merge(map_data, tw_fields, left_index=True, right_index=True)  
final_dataset['doc_id']=None
final_dataset['doc_num']=None
s = final_dataset["docs_ids"].str.split(pat = '\t',expand = True)
final_dataset['doc_id']=s[0]
final_dataset['doc_num']=s[1]
final_dataset.head(40) #displaying the first 3 rows
# Out:
#                        docs_ids  \
# 0    doc_1\t1575918182698979328
# 1    doc_2\t1575918151862304768
# 2    doc_3\t1575918140839673873
# 3    doc_4\t1575918135009738752
# 4    doc_5\t1575918119251419136
# 5    doc_6\t1575918105854984192
# 6    doc_7\t1575918095008681986
# 7    doc_8\t1575918088473788429
# 8    doc_9\t1575918083075555329
# 9   doc_10\t1575918057037303808
# 10  doc_11\t1575918052595552256
# 11  doc_12\t1575918038196666392
# 12  doc_13\t1575918028717707265
# 13  doc_14\t1575918018991099904
# 14  doc_15\t1575918018235813888
# 15  doc_16\t1575918012221333504
# 16  doc_17\t1575918004642402304
# 17  doc_18\t1575917983062380545
# 18  doc_19\t1575917982726860802
# 19  doc_20\t1575917943426535424
# 20  doc_21\t1575917938502254602
# 21  doc_22\t1575917915882373137
# 22  doc_23\t1575917865743663125
# 23  doc_24\t1575917833573179392
# 24  doc_25\t1575917821560864782
# 25  doc_26\t1575917776614871040
# 26  doc_27\t1575917773376540672
# 27  doc_28\t1575917720499109910
# 28  doc_29\t1575917719416979466
# 29  doc_30\t1575917717600681984
# 30  doc_31\t1575917715378044928
# 31  doc_32\t1575917699691167760
# 32  doc_33\t1575917671937232898
# 33  doc_34\t1575917642547834881
# 34  doc_35\t1575917640962277376
# 35  doc_36\t1575917617281658880
# 36  doc_37\t1575917614194647045
# 37  doc_38\t1575917551267332104
# 38  doc_39\t1575917512922783744
# 39  doc_40\t1575917502554513408
#
#                                                 Tweet  \
# 0   So this will keep spinning over us until 7 pm…...
# 1   Our hearts go out to all those affected by #Hu...
# 2   Kissimmee neighborhood off of Michigan Ave. \n...
# 3   I have this one tree in my backyard that scare...
# 4   @AshleyRuizWx @Stephan89441722 @lilmizzheidi @...
# 5   Ace Handyman Services hopes everyone was safe ...
# 6   Storm surge issues in Georgetown, SC #Hurrican...
# 7   Our thoughts are with the students, teachers, ...
# 8   #SouthCarolina braces for #HurricaneIan to mak...
# 23                    Kelly Bazzle 2022-09-30 18:37:45+00:00
# 24             Ekanem Etim-Offiong 2022-09-30 18:37:42+00:00
# 25         Kel The Goblin Queen  ✊ 2022-09-30 18:37:31+00:00
# 26                Jennifer Yvonne  2022-09-30 18:37:30+00:00
# 27  Ace Handyman Services Lakeland 2022-09-30 18:37:18+00:00
# 28                 Tampa Bay Water 2022-09-30 18:37:18+00:00
# 29                          Darwin 2022-09-30 18:37:17+00:00
# 30                     Jake Stofan 2022-09-30 18:37:17+00:00
# 31                        Storyful 2022-09-30 18:37:13+00:00
# 32                      Jay DeBard 2022-09-30 18:37:06+00:00
# 33     Southern Urbanism Quarterly 2022-09-30 18:36:59+00:00
# 34                  ✨Ꮛ𝒎𝒎𝒂 Ꮗ𝒂𝒕𝒔𝒐𝒏.✨ 2022-09-30 18:36:59+00:00
# 35                    Amy S Breaux 2022-09-30 18:36:53+00:00
# 36    NoLongerEssentialSandtrooper 2022-09-30 18:36:53+00:00
# 37                           ♊️‍♊️ 2022-09-30 18:36:38+00:00
# 38                          Jessie 2022-09-30 18:36:28+00:00
# 39        Mom Against Media 1776 ❌ 2022-09-30 18:36:26+00:00
#
#                                              Hashtags  Likes  Retweets  \
# 0     [{'text': 'HurricaneIan', 'indices': [63, 76]}]      0         0
# 1     [{'text': 'HurricaneIan', 'indices': [43, 56]}]      0         0
# 2     [{'text': 'HurricaneIan', 'indices': [45, 58]}]      0         0
# 3   [{'text': 'scwx', 'indices': [122, 127]}, {'te...      0         0
# 4   [{'text': 'HurricaneIan', 'indices': [159, 172]}]      0         0
# 5   [{'text': 'HurricaneIan', 'indices': [221, 234...      0         0
# 6     [{'text': 'HurricaneIan', 'indices': [37, 50]}]      0         0
# 7   [{'text': 'CloseUpDC', 'indices': [114, 124]},...      0         0
# 8   [{'text': 'SouthCarolina', 'indices': [0, 14]}...      0         0
# 9   [{'text': 'HurricaneIan', 'indices': [26, 39]}...      0         0
# 10    [{'text': 'HurricaneIan', 'indices': [55, 68]}]      0         0
# 11     [{'text': 'HurricaneIan', 'indices': [0, 13]}]      0         0
# 12  [{'text': 'HurricaneIan', 'indices': [63, 76]}...      1         2
# 13  [{'text': 'Carolinas', 'indices': [25, 35]}, {...      0         0
# 14  [{'text': 'HurricaneIan', 'indices': [262, 275]}]      0         0
# 15  [{'text': 'HurricaneIan', 'indices': [13, 26]}...      0         0
# 16  [{'text': 'Ian', 'indices': [50, 54]}, {'text'...      0         0
# 17  [{'text': 'BREAKING', 'indices': [0, 9]}, {'te...      0         0
# 18  [{'text': 'HurricaneIan', 'indices': [121, 134]}]      0         0
# 19    [{'text': 'HurricaneIan', 'indices': [84, 97]}]      0         0
# 20     [{'text': 'HurricaneIan', 'indices': [0, 13]}]      0         0
# 21  [{'text': 'vawx', 'indices': [10, 15]}, {'text...      0         0
# 22    [{'text': 'HurricaneIan', 'indices': [68, 81]}]      2         3
# 23  [{'text': 'HurricaneIan', 'indices': [227, 240...      1         0
# 24  [{'text': 'HurricaneIan', 'indices': [0, 13]},...      0         0
# 25  [{'text': 'HurricaneIan', 'indices': [46, 59]}...      0         0
# 26  [{'text': 'HurricaneIan', 'indices': [186, 199...      0         0
# 27  [{'text': 'HurricaneIan', 'indices': [221, 234...      0         0
# 28  [{'text': 'TampaBay', 'indices': [213, 222]}, ...      0         0
# 29  [{'text': 'HurricaneIan', 'indices': [0, 13]},...      1         1
# 30    [{'text': 'HurricaneIan', 'indices': [42, 55]}]      0         0
# 31  [{'text': 'HurricaneIan', 'indices': [106, 119]}]      1         1
# 32    [{'text': 'HurricaneIan', 'indices': [60, 73]}]      0         0
# 33  [{'text': 'Charleston', 'indices': [59, 70]}, ...      1         0
# 34  [{'text': 'HurricaneIan', 'indices': [154, 167...      1         0
# 35  [{'text': 'HurricaneIan', 'indices': [220, 233...      1         0
# 36  [{'text': 'florida', 'indices': [85, 93]}, {'t...      1         0
# 37    [{'text': 'HurricaneIan', 'indices': [17, 30]}]      0         0
# 38    [{'text': 'HurricaneIan', 'indices': [45, 58]}]      0         0
# 39  [{'text': 'Florida', 'indices': [0, 8]}, {'tex...      0         0
#
#                         Url  \
# 0   https://t.co/VROTxNS9rz
# 1                        {}
# 2   https://t.co/jf7zseg0Fe
# 3                        {}
# 4                        {}
# 5   https://t.co/BfpOq7tJE0
# 6   https://t.co/qWs0XJzGMx
# 7   https://t.co/eHZ9NKhCgA
# 8                        {}
# 9                        {}
# 10                       {}
# 11  https://t.co/BvcQeOLkBG
# 12                       {}
# 13  https://t.co/tR9dqjrpe4
# 14  https://t.co/iIEDQ3IbGx
# 15  https://t.co/zwZZqJiDno
# 16  https://t.co/biJyvS7Dz2
# 17                       {}
# 18                       {}
# 19                       {}
# 20                       {}
# 21                       {}
# 22  https://t.co/NqPpa1InTq
# 23                       {}
# 24                       {}
# 25  https://t.co/mM85uU1d6R
# 26                       {}
# 27  https://t.co/PRHlVXG9EM
# 28  https://t.co/0SyYYeOVnu
# 29                       {}
# 30  https://t.co/ReIlxvuT6D
# 31  https://t.co/QSYWjnn7qN
# 32  https://t.co/cbH5WlqqNF
# 33                       {}
# 34                       {}
# 35                       {}
# 36  https://t.co/SUOTYSyfWa
# 37                       {}
# 38  https://t.co/qzgYxuRKOc
# 39                       {}
#
#                                    preprocessed_tweet  doc_id  \
# 0   [keep, spin, us, 7, pm, go, away, alreadi, hur...   doc_1
# 1   [heart, go, affect, hurricaneian, wish, everyo...   doc_2
# 2   [kissimme, neighborhood, michigan, ave, hurric...   doc_3
# 3   [one, tree, backyard, scare, poltergeist, tree...   doc_4
# 4   [ashleyruizwx, stephan89441722, lilmizzheidi, ...   doc_5
# 5   [ace, handyman, servic, hope, everyon, safe, h...   doc_6
# 6   [storm, surg, issu, georgetown, sc, hurricanei...   doc_7
# 7   [thought, student, teacher, parent, commun, su...   doc_8
# 8   [southcarolina, brace, hurricaneian, make, lan...   doc_9
# 9   [piss, god, send, hurricaneian, florida, south...  doc_10
# 10  [today, edit, smoke, eater, photo, essay, hurr...  doc_11
# 11  [hurricaneian, offici, made, landfal, 2, 15, p...  doc_12
# 12  [togeth, rais, 20, 000, less, 24, hour, hurric...  doc_13
# 13  [best, hope, go, carolina, especi, mayor, tim,...  doc_14
# 14  [famou, landmark, cherri, grove, pier, north, ...  doc_15
# 15  [edg, hurricaneian, hit, part, southcarolina, ...  doc_16
# 16  [nation, ocean, atmospher, administr, ian, lat...  doc_17
# 17  [break, hurrican, ian, made, landfal, soutcaro...  doc_18
# 18  [yall, plot, scam, steal, fund, folk, legit, l...  doc_19
# 19  [xfinitysupport, busi, noth, help, us, affect,...  doc_20
# 20  [hurricaneian, still, monster, storm, everyon,...  doc_21
# 21  [import, vawx, inform, remnant, hurricaneian, ...  doc_22
# 22  [housedemocrat, pass, new, fund, bill, provid,...  doc_23
# 23  [heard, husband, unit, north, port, assist, fi...  doc_24
# 24  [hurricaneian, make, landfal, southcarolina, n...  doc_25
# 25  [sanibel, island, lighthous, hurricaneian, hur...  doc_26
# 26  [aftermath, disast, resist, take, advantag, vu...  doc_27
# 27  [ace, handyman, servic, hope, everyon, safe, h...  doc_28
# 28  [clean, safe, water, essenti, storm, region, w...  doc_29
# 29  [hurricaneian, ian, make, 3rd, landfal, george...  doc_30
# 30  [flood, riversid, water, impact, hurricaneian,...  doc_31
# 31  [strong, gust, wind, tropic, storm, ian, blew,...  doc_32
# 32  [ryanhallyal, western, edg, hurrican, ian, day...  doc_33
# 33  [devast, south, histor, downtown, charleston, ...  doc_34
# 34  [safeti, well, check, fellow, florida, friend,...  doc_35
# 35  [itsbethbook, hi, beth, happi, amp, reliev, se...  doc_36
# 36  [vent, inspir, everi, convers, mother, disconn...  doc_37
# 37                              [power, hurricaneian]  doc_38
# 38  [final, enough, cell, signal, hurricaneian, se...  doc_39
# 39  [florida, love, publix, hurricaneian, co, 310w...  doc_40
#
#                 doc_num
# 0   1575918182698979328
# 1   1575918151862304768
# 2   1575918140839673873
# 3   1575918135009738752
# 4   1575918119251419136
# 5   1575918105854984192
# 6   1575918095008681986
# 7   1575918088473788429
# 8   1575918083075555329
# 9   1575918057037303808
# 10  1575918052595552256
# 11  1575918038196666392
# 12  1575918028717707265
# 13  1575918018991099904
# 14  1575918018235813888
# 15  1575918012221333504
# 16  1575918004642402304
# 17  1575917983062380545
# 18  1575917982726860802
# 19  1575917943426535424
# 20  1575917938502254602
# 21  1575917915882373137
# 22  1575917865743663125
# 23  1575917833573179392
# 24  1575917821560864782
# 25  1575917776614871040
# 26  1575917773376540672
# 27  1575917720499109910
# 28  1575917719416979466
# 29  1575917717600681984
# 30  1575917715378044928
# 31  1575917699691167760
# 32  1575917671937232898
# 33  1575917642547834881
# 34  1575917640962277376
# 35  1575917617281658880
# 36  1575917614194647045
# 37  1575917551267332104
# 38  1575917512922783744
# 39  1575917502554513408

# %% [markdown]
# ##PROJECT PART 2: Indexing and Evaluation

# %% [markdown]
# ###Indexing

# %% [markdown]
# **Inverted Index tfidf function**

# %%
def create_index_tfidf(dataset, num_documents):
    """
    Implement the inverted index and compute tf, df and idf
    
    Argument:
    lines -- collection of Wikipedia articles
    num_documents -- total number of documents
    
    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of document these keys appears in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """
    index = defaultdict(list)
    tf = defaultdict(list)  # term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  # document frequencies of terms in the corpus
    idf = defaultdict(float)
    title_index = defaultdict(str)
    likes = defaultdict(str)
    retweets = defaultdict(str)

    for pos, line in enumerate(dataset['preprocessed_tweet']):  # Remember, lines contain all documents from file
 
        page_id = dataset['doc_id'][pos]
        title_index[page_id] = dataset['Tweet'][pos] #each of the tweets (full text before being preprocessed)
        likes[page_id] = dataset['Likes'][pos]
        retweets[page_id] = dataset['Retweets'][pos] 
        current_page_index = {}

        for position, term in enumerate(line):  ## terms contains page_title + page_text
            try:
                # if the term is already in the dict append the position to the corresponding list
                current_page_index[term][1].append(position) 
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[term] = [page_id, array('I', [position])]  #'I' indicates unsigned int (int in Python)

        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a document.
        norm = 0
        for term, posting in current_page_index.items():
            # posting will contain the list of positions for current term in current document. 
            # posting ==> [current_doc, [list of positions]] 
            # you can use it to infer the frequency of current term.
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        # calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in current_page_index.items():
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting[1])/norm,4)) ## SEE formula (1) above
            #increment the document frequency of current term (number of documents containing the current term)
            df[term] = df[term]+1 # increment DF for current term

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

        # Compute IDF following the formula (3) above. HINT: use np.log
        for term in df:
            idf[term] = np.round(np.log(float(num_documents/df[term])), 4)

    return index, tf, df, idf,title_index, likes, retweets


index, tf, df, idf, title_index, likes, retweets = create_index_tfidf(final_dataset, len(final_dataset))

# %%
def rank_documents(terms, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    docs -- list of documents/tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked documents and documents scores
    """

    # We are interested only on the element of the docVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    doc_vectors = defaultdict(lambda: [0] * len(terms)) # We call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # computing the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):
            # Example of [doc_index, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]  # TODO: check if multiply for idf

    # Calculating the score of each doc 
    # Computing the cosine similarity between queyVector and each docVector:

    doc_scores = [[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items()]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_scores = [x[0] for x in doc_scores]
    if len(doc_scores) == 0:
        print("No results found, try again")
        #query1=input()
        #docs = search_tf_idf(query,index)
    return result_docs, result_scores

# %%
def search_tf_idf(query, index):
    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs = [posting[0] for posting in index[term]]
            
            # docs = docs Union term_docs
            docs |= set(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    ranked_docs,ranked_scores = rank_documents(query, docs, index, idf, tf)
    return ranked_docs, ranked_scores

# %% [markdown]
# ##PROJECT PART 3: Ranking

# %% [markdown]
# ###Ranking score

# %% [markdown]
# ####Part1

# %% [markdown]
# #####TF-IDF + cosine similarity:

# %% [markdown]
# ######QUERIES TF-IDF + COSINE SIMILARITY

# %%
#QUERY 1
print("hurricane ian:\n")
q1 = input()
ranked_docs1, ranked_scores1 = search_tf_idf(q1, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs1)))
i=0
for d_id in ranked_docs1[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, ranked_scores1[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# hurricane ian:
#
# hurricane ian
#
# ======================
# Top 20 results out of 1095 for the searched query:
#
# page_id= doc_634 - doc_score: 1.9399946808643298 - original_tweet: Hurricane IAN #Ian #HurricaneIan #HurricanIan #Huracan #HuracanIan #Hurricane https://t.co/HbllO4Q3vB - likes: 1 - retweets: 0
#
# page_id= doc_495 - doc_score: 1.9303480851923807 - original_tweet: Hurricane Ian be like
#
# “You all haven’t had any hurricanes around here lately so I’m just gonna take my time on the East Coast.”
#
# #HurricaneIan #Ian #Hurricane - likes: 0 - retweets: 0
#
# page_id= doc_1025 - doc_score: 1.8953512111269468 - original_tweet: @colbertlateshow @DirectRelief @ConvoyofHope @WCKitchen @GlobalGiving @StephenAtHome #hope7cc How to help people with the aftermath of Hurricane Ian. #ian #HurricaneIan #Hurricane_Ian #hurricane #charity #PeopleHelpingPeople https://t.co/AKcI4PlhEY - likes: 0 - retweets: 0
#
# page_id= doc_2140 - doc_score: 1.814775192576548 - original_tweet: #hurricaneian
# The perpetual hurricane Ian - likes: 0 - retweets: 0
#
# page_id= doc_205 - doc_score: 1.4108141049687033 - original_tweet: Drone footage: "Edge" of Hurricane Ian seen from Knoxville, TN
# @ryanhallyall #Ian #HurricaneIan https://t.co/olgPFYclUQ - likes: 4 - retweets: 1
#
# page_id= doc_3508 - doc_score: 1.4006356233708848 - original_tweet: If you were affected by Hurricane Ian and are seeking resources, click the link below:
#
# https://t.co/FdGPJq7yGu
#
# #hurricaneian #hurricane #fema #flooding - likes: 0 - retweets: 0
#
# page_id= doc_3169 - doc_score: 1.4006356233708848 - original_tweet: Hurricane Ian has went around my area! LETS GOOOOOO! Now what do I do with all these cans of food😅 #HurricaneIan #Hurricane https://t.co/fwVPExRGyi - likes: 1 - retweets: 0

# %%
#QUERY 2
print("south carolina:\n")
q2 = input()
ranked_docs2, ranked_scores2 = search_tf_idf(q2, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs2)))
i=0
for d_id in ranked_docs2[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, ranked_scores2[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# south carolina:
#
# south carolina
#
# ======================
# Top 20 results out of 358 for the searched query:
#
# page_id= doc_174 - doc_score: 4.945604303400691 - original_tweet: South Carolina #HurricaneIan here we go - likes: 1 - retweets: 0
#
# page_id= doc_254 - doc_score: 4.423348488961577 - original_tweet: South Carolina #HurricaneIan https://t.co/yTA4dFUC2V - likes: 0 - retweets: 0
#
# page_id= doc_493 - doc_score: 4.355493129784444 - original_tweet: Just south of Myrtle Beach in South Carolina. #HurricaneIan #Ian #ScWx https://t.co/ErHr5X5cQQ - likes: 1 - retweets: 0
#
# page_id= doc_480 - doc_score: 4.037591353296323 - original_tweet: South Carolina friends, you OK so far?? #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_48 - doc_score: 4.037591353296323 - original_tweet: Sending love and prayers to South Carolina #HurricaneIan 🙏 ❤️ - likes: 0 - retweets: 0
#
# page_id= doc_1401 - doc_score: 4.037591353296323 - original_tweet: #hurricaneian won't go away prayers for South Carolina - likes: 1 - retweets: 0
#
# page_id= doc_1444 - doc_score: 3.766377481215798 - original_tweet: #HurricaneIan nears landfall in South Carolina - Will impact both Carolinas and Virginia, reports Karen Graham. https://t.co/qttgs1Stbf - likes: 0 - retweets: 0
#
# page_id= doc_2874 - doc_score: 3.738876853370922 - original_tweet: From .@ABCNews4 in Charleston, South Carolina - #HurricaneIan https://t.co/TLCRoQ3VvD - likes: 0 - retweets: 0
#
# page_id= doc_2834 - doc_score: 3.738876853370922 - original_tweet: from .@ABCNews4 in Charleston, South Carolina - #HurricaneIan https://t.co/nbxQROQSKW - likes: 0 - retweets: 0
#
# page_id= doc_2505 - doc_score: 3.738876853370922 - original_tweet: ⚠️ #HurricaneIan about to make landfall on South Carolina! https://t.co/X61NAwpsx6 - likes: 2 - retweets: 1
#
# page_id= doc_249 - doc_score: 3.738876853370922 - original_tweet: #HurricaneIan makes landfall in South Carolina... https://t.co/vKik1OyOgQ - likes: 1 - retweets: 0
#
# page_id= doc_1078 - doc_score: 3.738876853370922 - original_tweet: Now South Carolina is getting hammered by #HurricaneIan 😫 https://t.co/fnGkXXhKM8 - likes: 0 - retweets: 0
#
# page_id= doc_1035 - doc_score: 3.738876853370922 - original_tweet: GET VACCINATED SOUTH CAROLINA, #HurricaneIan is coming! 🤦‍♂️ #FJB - likes: 0 - retweets: 0
#
# page_id= doc_595 - doc_score: 3.497531363364968 - original_tweet: #HurricaneIan headed towards Charleston, South Carolina https://t.co/Pm6W0pAeYB - likes: 0 - retweets: 0
#
# page_id= doc_3372 - doc_score: 3.497531363364968 - original_tweet: Be safe all in South Carolina
# and all around too during
# this time.
# Prayers are with yall🙏🙏
# #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_2197 - doc_score: 3.497531363364968 - original_tweet: Storm Serge in South Carolina due to #HurricaneIan https://t.co/48E9hOwHyP - likes: 0 - retweets: 0
#
# page_id= doc_1522 - doc_score: 3.497531363364968 - original_tweet: UPDATE: #HurricaneIan has strengthened to a Category 1 hurricane ahead of its second U.S. landfall on Friday along the South Carolina coast. Sustained winds around 85mph and up to 10 inches of rain are expected for parts of South Carolina. https://t.co/fLdtayDzs1 - likes: 0 - retweets: 0
#
# page_id= doc_1285 - doc_score: 3.497531363364968 - original_tweet: The view as #HurricaneIan roars ashore in South Carolina https://t.co/RybeeJsyjj - likes: 3 - retweets: 0
#
# page_id= doc_2607 - doc_score: 3.4381687541540034 - original_tweet: HOW TO REPORT AN OUTAGE WHERE YOU ARE:
# - North Carolina: https://t.co/yy9LQ9L3Ti
# - South Carolina: https://t.co/OZ4hBocNml
# #HurricaneIan #PowerOutage #GasOutage #Water - likes: 0 - retweets: 0
#
# page_id= doc_1879 - doc_score: 3.346270310576701 - original_tweet: #HurricaneIan #Ian #Carolinas #ncwx #scwx #Florida #Charleston #SC
# Myrtle Beach Volleyball Live Cam South Carolina
# https://t.co/wPjObKMdYp - likes: 0 - retweets: 0

# %%
#QUERY 3
print("help people:\n")
q3 = input()
ranked_docs3, ranked_scores3 = search_tf_idf(q3, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs3)))
i=0
for d_id in ranked_docs3[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, ranked_scores3[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# help people:
#
# help people
#
# ======================
# Top 20 results out of 556 for the searched query:
#
# page_id= doc_3682 - doc_score: 4.729731010467683 - original_tweet: Good morning lovelies. Yesterday my employer sent an email about donations to help Florida #HurricaneIan victims. But I wanna hear from YOU, how can people help? The theme parks will be ok, I’m concerned about the PEOPLE! What can people do to help? https://t.co/ERiJukIPVN - likes: 3 - retweets: 0
#
# page_id= doc_3454 - doc_score: 4.038435214957499 - original_tweet: Never thought I'd see the day where people say a state should receive no aid funding because of a letter next to a governor's name. Disgusting that people would rather make this tragedy political than see people get help. Some people have truly lost it.
# #HurricaneIan #Florida - likes: 0 - retweets: 0
#
# page_id= doc_812 - doc_score: 3.9145908322646146 - original_tweet: Looking for organizations that are providing help to #HurricaneIan victims in Central Florida. We're trying to connect groups with people who need help. Know of any groups out there that people can contact? - likes: 1 - retweets: 0
#
# page_id= doc_3428 - doc_score: 3.821922827676192 - original_tweet: Why people hurt people’s feelings? #PonniyinSelvan #HurricaneIan #CovidIsNotOver - likes: 0 - retweets: 0
#
# page_id= doc_2027 - doc_score: 3.5940431564013524 - original_tweet: @KEYCNewsNow Thanks for sharing how the Red Cross is helping those affected by #hurricaneian and raising awareness on how people can help! - likes: 0 - retweets: 0
#
# page_id= doc_280 - doc_score: 3.4395585669802236 - original_tweet: The news coverage of #HurricaneIan in #Florida has gotten on my nerves. No Black people, no Hispanic people, no poor people.
#
# Just overturned yachts.
#
# Where are the trailers, the projects, the middle class neighborhoods? - likes: 0 - retweets: 0
#
# page_id= doc_2753 - doc_score: 3.426106988857837 - original_tweet: Don’t send money to people for Hurricane Ian if you can’t verify they live there or that they can actually help. Lots of evil, greedy people taking advantage of a very dark time. #HurricaneIan - likes: 1 - retweets: 0
#
# page_id= doc_1300 - doc_score: 3.2613247658448175 - original_tweet: It has been so encouraging how many lawyers &amp; people I’ve seen on @Twitter offering to help with #HurricaneIan! We are all better when we help others! https://t.co/1Mfh8Orksy - likes: 1 - retweets: 0
#
# page_id= doc_191 - doc_score: 3.1963084870009704 - original_tweet: @SenGaryPeters @SenStabenow
# Just wondering why you are quiet about the helping the people in Florida and SC after the #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3730 - doc_score: 3.1109585154008847 - original_tweet: #HurricaneIan caused devastation in Florida leaving 2.6M+ people without power.
#
# Our friends @victoryatl are jumping in to help hurricane survivors to meet their most immediate needs. Would you consider a gift to help people in desperate need?
#
# https://t.co/FZAGyolZhY https://t.co/S2zWHRSBRa - likes: 2 - retweets: 0
#
# page_id= doc_898 - doc_score: 3.032321462915412 - original_tweet: @DonaldJTrumpJr Don't even TRY to open a charity to "help the people of Florida recover from #HurricaneIan..." 😂😂😂 - likes: 1 - retweets: 0
#
# page_id= doc_3666 - doc_score: 2.924914757081596 - original_tweet: Help people affected by #HurricaneIan — your donation enables the Red Cross to prepare for, respond to, and help people recover from this disaster.
#
# Visit https://t.co/McLHRYWecc, call 1-800-RED CROSS, or text the word IAN to 90999 to make a $10 donation. https://t.co/y7SDJ9vTMo - likes: 1 - retweets: 1
#
# page_id= doc_3579 - doc_score: 2.8913501615085284 - original_tweet: @GovRonDeSantis maybe you should have saved that illegal shipping of people money to help the citizens of Florida #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3560 - doc_score: 2.8669369184442592 - original_tweet: Join @MLS and @RedCross to help people affected by #HurricaneIan. Your donation will help emergency preparedness, response, and recovery from this disaster: https://t.co/4mohwOmeF0 https://t.co/BUC7TeF5Fq - likes: 7 - retweets: 1
#
# page_id= doc_3577 - doc_score: 2.803735213394128 - original_tweet: Where the F is @fema or any electrical truck or any help at all. People are being found dead on rooftops now cause no help came.
#
# @POTUS said there was assistance, NOTHING!!!
#
# #HurricaneIan #Hurricane #Ian https://t.co/Fuvg4RJsN9 - likes: 0 - retweets: 0
#
# page_id= doc_453 - doc_score: 2.7973119645923297 - original_tweet: Hey national, state, and local candidates for office! Do not send fundraising appeals to people in the path of #HurricaneIan. While my family and I are safe, any disposable income will be going to help local organizations supporting people impacted. #SC  https://t.co/MqQENyUSk3 - likes: 4 - retweets: 2
#
# page_id= doc_213 - doc_score: 2.780883101403511 - original_tweet: #CajunNavy is in #NorthFortMyers and they need people to bring food, water and diapers to them so they can distribute it to the people. #HurricaneIan
# https://t.co/Us4vTa3bgv
# #Florida #FortMyers - likes: 0 - retweets: 0
#
# page_id= doc_584 - doc_score: 2.768599640555596 - original_tweet: Join FOX in our support of @RedCross relief efforts and help people affected by #HurricaneIan:  https://t.co/rg8EFwC0NC - likes: 2 - retweets: 1
#
# page_id= doc_2726 - doc_score: 2.768599640555596 - original_tweet: Join Fox in our support of @RedCross relief efforts and help people affected by #HurricaneIan:  https://t.co/VaepU9Kkt9 - likes: 0 - retweets: 1
#
# page_id= doc_1906 - doc_score: 2.73583482957454 - original_tweet: With your help, we can support the rebuilding &amp; recovery efforts in the areas affected by #HurricaneIan &amp; #HurricaneFiona. Together w/ @MiamiHerald/ @elNuevoHerald we’ve launched Operations Helping Hands to help the people affected by these powerful storms.https://t.co/ekehDZ5OpB https://t.co/hrixpYCr5f - likes: 1 - retweets: 3

# %%
#QUERY 4
print("flood damage:\n")
q4 = input()
ranked_docs4, ranked_scores4 = search_tf_idf(q4, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs4)))
i=0
for d_id in ranked_docs4[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, ranked_scores4[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# flood damage:
#
# flood damage
#
# ======================
# Top 20 results out of 495 for the searched query:
#
# page_id= doc_3288 - doc_score: 2.841599791861431 - original_tweet: We're still without power &amp; no estimate for restoration so we went to a hotel. There is minor damage to our roof &amp; some flood damage but nothing major. Everything in our fridge &amp; freezer is gone. But it could've been much worse!! #HurricaneIan - likes: 17 - retweets: 0
#
# page_id= doc_3909 - doc_score: 2.758932621188974 - original_tweet: #Map: Where #Hurricane #Ian Hit #Florida Hardest
# Officials are still working to assess extent of #damage caused by #HurricaneIan &amp; its subsequent #floods, as reports emerge of destroyed #homes, damaged #power lines &amp; disrupted #water supplies. #stormsurge
# https://t.co/UFlmjVYDLk - likes: 0 - retweets: 0
#
# page_id= doc_2687 - doc_score: 2.702346514124129 - original_tweet: Just over Blind Pass Bridge on #Sanibel #Captiva Rd. Significant damage here. Structures missing and damages. #Ian #HurricaneIan #flwx https://t.co/0a9vCgoVD5 - likes: 1 - retweets: 0
#
# page_id= doc_1493 - doc_score: 2.6598819386662127 - original_tweet: It’s not the wind that’s so bad for us in the lowcountry ; like in Florida it’s the wind I worry about. Here it’s the FLOODING. The lowcountry floods during regular rain storms; hurricanes can flood out so many homes so fast here. #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_585 - doc_score: 2.647263853641589 - original_tweet: Ian Photos: Flooded Homes, Washed-Out Roads, Broken Power Poles - @Bloomberg shows us the damage.  #HurricaneIan
#
# https://t.co/7hw9gh5GG6 - likes: 0 - retweets: 0
#
# page_id= doc_2515 - doc_score: 2.647263853641589 - original_tweet: So yeah, folks don't have power and are dealing with intense flooding/property damage, but hey, the theme parks are open (🤦‍♀️) #Florida #HurricaneIan https://t.co/H0R3SfESTx - likes: 3 - retweets: 1
#
# page_id= doc_3743 - doc_score: 2.610777379537626 - original_tweet: . @GovRonDeSantis is requesting quick insurance claim settlements for Floridians.
#
# We don’t need the National Flood Insurance Program (NFIP) fighting w/ private insurance carriers over wind vs. flood damage. I will be watching this closely.
#
# Pray for our state.  #HurricaneIan - likes: 315 - retweets: 85
#
# page_id= doc_1862 - doc_score: 2.5957766956675017 - original_tweet: This is near where I live. Flood didn't affect me. Caused by flooding of #EconRiver #EconTrail #HurricaneIan #FloridaLife https://t.co/G1r0teVGAj - likes: 7 - retweets: 2
#
# page_id= doc_2488 - doc_score: 2.5078748094344205 - original_tweet: If you are in a flood zone, you will be required by your mortgage company to carry a flood policy.  Here is what it covers.
# #HurricaneIan #floodinsurance https://t.co/FEiq7SI4cq - likes: 0 - retweets: 0
#
# page_id= doc_1374 - doc_score: 2.5078748094344205 - original_tweet: just had an advert pop up for help #floods in pakistan. how about helping the floods for #miami and #Hurricane_Ian #hurricaneian - likes: 0 - retweets: 0
#
# page_id= doc_1317 - doc_score: 2.5078748094344205 - original_tweet: https://t.co/Tzw965uBgX
#
# Here is the SERFC's Florida briefing for flooding from #hurricaneIan #flwx #flood https://t.co/cd4ljIyNmI - likes: 0 - retweets: 0
#
# page_id= doc_1279 - doc_score: 2.4291293121015225 - original_tweet: Checking in from central Florida. We came through #HurricaneIan fine. Just some minor flooding and a little tiny bit of structural damage to barns and such. Yard is a mess. No electricity. Day 2. - likes: 0 - retweets: 0
#
# page_id= doc_1257 - doc_score: 2.4291293121015225 - original_tweet: We are thinking about all of our colleagues, partners, and communities in #Florida and the #Southeast that are affected by #HurricaneIan, and are hoping that everyone is staying safe as the region experiences severe flooding and damage. https://t.co/CzzQBWGJ9H - likes: 0 - retweets: 0
#
# page_id= doc_1691 - doc_score: 2.3952049884063835 - original_tweet: Flood Safety: If you’ve been affected by flooding, please be aware of floodwater contaminants!
#
# ❌Do not drink floodwater
# ❌Do not cook, clean, or brush teeth with flood water
# ✔️Cover open wounds
# ✔️Limit exposure to floodwater
#
# #HurricaneIan https://t.co/GPIF3Oj7mP - likes: 1 - retweets: 2
#
# page_id= doc_1226 - doc_score: 2.3904932040512556 - original_tweet: FRIDAY MORNING AFTER IAN🌀 The damage is no longer hidden under water in SOME LOCATIONS! #HurricaneIan damage, Border of Port Charlotte &amp; Engelwood.#flwx
# 📸 @peaceluvorganix #TheWeatherlady #KindnessForSteve https://t.co/cWsU1RrFHg - likes: 1 - retweets: 0
#
# page_id= doc_498 - doc_score: 2.367712790697037 - original_tweet: Due to flooding from #HurricaneIan we will not be releasing an episode this week. We will be assessing the damage to our power, internet, and equipment and will be back releasing episodes as soon as we are able. - likes: 1 - retweets: 0
#
# page_id= doc_339 - doc_score: 2.340046345068879 - original_tweet: as #Biden spends 3 of 5 minutes talking about Russia he hasn't a clue of the damage done in Florida. Drone footage shows #HurricaneIan damage in Fort Myers https://t.co/XHLKle54mp via @YouTube - likes: 0 - retweets: 0
#
# page_id= doc_2995 - doc_score: 2.3105318914583792 - original_tweet: You guys… #HurricaneIan Update ☔️
#
# Versailles is a DISASTER! Water flooded the house and we can’t even wrap our heads around the damage. Luckily we’re ok. 💗
#
# Everybody please stay safe! 🙏❤️
# https://t.co/xH9nUqnbaA - likes: 33 - retweets: 5
#
# page_id= doc_2929 - doc_score: 2.293039044653483 - original_tweet: Damages from the hurricane to my family’s condo ;-; we’re grateful no severe damage was done to the building itself but wow, I’m staying here in a week &amp; I’m just so sad to see it like this 😭😭
#
# #Vtuber #HurricaneIan #DaytonaBeach #Florida #TheTowers https://t.co/8SEy7UCLqZ - likes: 14 - retweets: 3
#
# page_id= doc_824 - doc_score: 2.2893342083024515 - original_tweet: https://t.co/eo9loHhTbh
#
# Here is the Decision Support Briefing addressing potential flooding in the Carolinas and Virginia from #HurricaneIan #flood https://t.co/SxlCiVJgpR - likes: 1 - retweets: 2

# %%
#QUERY 5
print("storm in florida:\n")
q5 = input()
ranked_docs5, ranked_scores5 = search_tf_idf(q5, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs5)))
i=0
for d_id in ranked_docs5[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, ranked_scores5[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# storm in florida:
#
# storm in florida
#
# ======================
# Top 20 results out of 1163 for the searched query:
#
# page_id= doc_3189 - doc_score: 2.29995780442169 - original_tweet: Storm Surge as #Ian moves towards South Carolina
#
# #SouthCarolina #HurricaneIan #Hurricane #Storm #Climate #Viral #Rain #Tornado #Tropicswx #SCwx
#
# VC: Palmetto Storm Chasers https://t.co/Vh1YQuwDET - likes: 1 - retweets: 1
#
# page_id= doc_2226 - doc_score: 2.1240859636958525 - original_tweet: #HurricaneIan is no anomaly. The #ClimateCrisis is making #storms more powerful. These kind of storms will be the #NewNormal
#
# Hurricane Ian is the fifth most powerful storm to ever hit USA. Only four other hurricanes have made landfall with sustained winds of more than 155mph - likes: 5 - retweets: 2
#
# page_id= doc_1714 - doc_score: 2.002709622913232 - original_tweet: VDOT completing storm preparations in advance of Tropical Storm Ian's arrival https://t.co/7WU3pFba3s #ian #hurricaneian - likes: 0 - retweets: 0
#
# page_id= doc_1822 - doc_score: 1.9461498994873172 - original_tweet: ✅Be prepared before the ⛈ storm
#
# Get instant alerts about the storm via 🔔notifications
#
# https://t.co/I3iNJYUggB
#
# #hurricaneian #EnergyUnited2022 https://t.co/y23qEh0yQ5 - likes: 0 - retweets: 0
#
# page_id= doc_3596 - doc_score: 1.9106811095735585 - original_tweet: Watching a storm come in a few years ago in South Florida. I always worried about my East Coast friends and hurricanes - never the West. These storms are no joke. Hope everyone in Ian’s path stays safe and dry 🌴🌞 #hurricaneian #florida #hurricane #staysafe 💚 https://t.co/FOk1vfbuRB - likes: 0 - retweets: 0
#
# page_id= doc_3475 - doc_score: 1.8462414829247524 - original_tweet: Yesterday after the storm #HurricaneIan https://t.co/igI6Z0mvGp - likes: 0 - retweets: 0
#
# page_id= doc_3311 - doc_score: 1.8462414829247524 - original_tweet: Doing good here but the storm is picking up for sure. #HurricaneIan - likes: 3 - retweets: 0
# #Ian #BonitaSprings #HurricaneIan #Hurricane #Storm #Climate #Viral #Rain #Tornado #Tropicswx #FLwx #Rescue https://t.co/mh8tf0g8CU - likes: 19 - retweets: 3
#
# page_id= doc_1573 - doc_score: 1.6191768998280143 - original_tweet: During our @ActionNewsJax storm coverage, I reported on the back of a special military-style truck driven by to give you all a better view of the #HurricaneIan storm surge in St. Augustine. Thank you David Gilliam for the ride! https://t.co/v40eXyAWuN - likes: 7 - retweets: 2

# %% [markdown]
# #####Your-score + cosine similarity:

# %%
ourN = len(final_dataset['doc_id'])
likest = dict(zip(final_dataset['doc_id'],final_dataset['Likes']))
retweetst = dict(zip(final_dataset['doc_id'],final_dataset['Retweets']))

# %%
def our_rank_documents(terms, docs, index, idf, tf, mg, rt):
    """
    Perform the ranking of the results of a search based on the tf-idf weights and a popularity score
    
    Argument:
    terms -- list of query terms
    docs -- list of documents/tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    mg -- total number of likes the tweet has
    rt -- total number of retweets the tweet has
    

    
    Returns:
    Print the list of ranked documents and documents scores
    """

    # We are interested only on the element of the docVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    doc_vectors = defaultdict(lambda: [0] * len(terms)) # We call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # computing the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):
            # Example of [doc_index, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                likes = mg[doc] 
                retweets = rt[doc]
                popularity_score = 0.5*math.log2(1+likes)+ 1*math.log2(1+retweets)
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term] + 0.5*(popularity_score)

    # Calculating the score of each doc 
    # Computing the cosine similarity between queyVector and each docVector:

    doc_scores = [[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items()]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_scores = [x[0] for x in doc_scores]
    if len(doc_scores) == 0:
        print("No results found, try again")
        #query1=input()
        #docs = search_tf_idf(query,index)
    return result_docs, result_scores

# %%
def our_search(query, index, mg, rt):
    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs = [posting[0] for posting in index[term]]
            
            # docs = docs Union term_docs
            docs |= set(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    ranked_docs,ranked_scores = our_rank_documents(query, docs, index, idf, tf, mg, rt)
    return ranked_docs, ranked_scores

# %% [markdown]
# ######QUERIES OUR SCORE + COSINE SIMILARITY

# %%
 #QUERY 1:
print("hurricane ian:\n")
our_query = input()
our_ranking_docs1,our_ranking_scores1 = our_search(our_query, index, likest, retweetst)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(our_ranking_docs1)))
i=0
for d_id in our_ranking_docs1[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, our_ranking_scores1[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# hurricane ian:
#
# hurricane ian
#
# ======================
# Top 20 results out of 1095 for the searched query:
#
# page_id= doc_3636 - doc_score: 11.17114744109913 - original_tweet: Hurricane Ian heads towards South Carolina after striking Florida.
#
# The death toll in Florida has risen to 21. We are praying from Israel for all those affected. Our hearts are with you. #HurricaneIan https://t.co/ArU7CFOZwh - likes: 151 - retweets: 46
#
# page_id= doc_1950 - doc_score: 10.349467236370877 - original_tweet: Wow! You can start to see #flooding from #HurricaneIan on one of the Charleston, #SouthCarolina livecams right now. Lets hope it doesn't get much worse. #Hurricane #Ian https://t.co/2pXRcxaBjg - likes: 67 - retweets: 40
#
# page_id= doc_1613 - doc_score: 9.725796725837302 - original_tweet: Flooding in downtown Charleston South Carolina happening right now due to Hurricane Ian. Many of the roads around the city are impassible, and more rain expected. I will continue covering the flood levels and showing the conditions. #hurricaneian #charleston #southcarolina #scwx https://t.co/62LGGbTHYC - likes: 80 - retweets: 28
#
# page_id= doc_1860 - doc_score: 8.783203010433763 - original_tweet: #Charleston #Hurricane #IAN  #SouthCarolina  #Ian
#  #TropicalStormIan #HurricaneIan  #MyrtleBeach  #Savannah  #NorthCarolina #OuterBanks #Augusta  #Wilmington #Jacksonville #EdistoIsland #Florida
# Market and Church Streets https://t.co/V6NxnQjBh9 - likes: 31 - retweets: 18
#
# page_id= doc_3521 - doc_score: 8.594019749415478 - original_tweet: Today, nearly 6,000 National Guard members from multiple states continue to support Hurricane Ian response efforts, and we’ll stay as long as we are needed.
#
# More: https://t.co/faGsQZieAB
# 📷: https://t.co/4u9ejpfIAc
# @FLGuard #HurricaneIan https://t.co/4VweLOVxaz - likes: 51 - retweets: 17
#
# page_id= doc_1335 - doc_score: 8.582228636911461 - original_tweet: WATCH: After ravaging Florida, a strengthened Hurricane Ian has made landfall in South Carolina and is predicted to enter North Carolina soon.  #Florida #NorthCarolina #SouthCarolina #USA #HurricaneIan #Environment https://t.co/LIAALDsxeP - likes: 31 - retweets: 21
#
# page_id= doc_819 - doc_score: 8.16459456369266 - original_tweet: WATCH: Hurricane Ian pushes sea water to the coast of South Carolina. #HurricaneIan #SouthCarolina #Environment https://t.co/ZIGtxaM7WB - likes: 33 - retweets: 13
#
# page_id= doc_811 - doc_score: 7.973477665051528 - original_tweet: Hurricane #Ian is gradually making landfall over South Carolina, northeast of Charleston.
#
# Latest radar → https://t.co/CMYwPHQBml #HurricaneIan https://t.co/4tUbq1wZ0l - likes: 20 - retweets: 16
#
# page_id= doc_2504 - doc_score: 6.803070436985807 - original_tweet: BREAKING: The center of Hurricane Ian is only about 50 miles from making landfall in South Carolina, as of the 11 a.m. update from the National Hurricane Center, which noted that the storm was “accelerating toward the South Carolina Coast.”
#
# Thoughts??
#
# #HurricaneIan #Lovelytitv https://t.co/j9hd26NUQS - likes: 20 - retweets: 7
#
# page_id= doc_87 - doc_score: 6.797158362780928 - original_tweet: 🌀📌 BREAKING: #HurricaneIan has made its 4th landfall near Georgetown #SCwx as a Cat 1 hurricane.
#
# @News12Weather #StormHour #Ian https://t.co/2bBVs8cIc6 - likes: 5 - retweets: 14

# %%
#QUERY 2:
print("south carolina:\n")
our_query2 = input()
our_ranking_docs2,our_ranking_scores2 = our_search(our_query2, index, likes, retweets)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(our_ranking_docs2)))
i=0
for d_id in our_ranking_docs2[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, our_ranking_scores2[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# south carolina:
#
# south carolina
#
# ======================
# Top 20 results out of 358 for the searched query:
#
# page_id= doc_3636 - doc_score: 19.2676408266899 - original_tweet: Hurricane Ian heads towards South Carolina after striking Florida.
#
# The death toll in Florida has risen to 21. We are praying from Israel for all those affected. Our hearts are with you. #HurricaneIan https://t.co/ArU7CFOZwh - likes: 151 - retweets: 46
#
# page_id= doc_2684 - doc_score: 18.5337572514716 - original_tweet: 1140a: Eye of #HurricaneIan just 40-50 miles offshore South Carolina. Landfall between Charleston and Myrtle Beach next few hours. https://t.co/XyOP10MTHE - likes: 84 - retweets: 42
#
# page_id= doc_1613 - doc_score: 16.729819518069114 - original_tweet: Flooding in downtown Charleston South Carolina happening right now due to Hurricane Ian. Many of the roads around the city are impassible, and more rain expected. I will continue covering the flood levels and showing the conditions. #hurricaneian #charleston #southcarolina #scwx https://t.co/62LGGbTHYC - likes: 80 - retweets: 28
#
# page_id= doc_1706 - doc_score: 15.924704164218682 - original_tweet: There are currently more than 70 @NWS warnings, watches and alerts in effect for South Carolina: https://t.co/tIGXlXxsjf
#
# #scwx #HurricaneIan #sctweets - likes: 27 - retweets: 25
#
# page_id= doc_1335 - doc_score: 15.817840254067459 - original_tweet: WATCH: After ravaging Florida, a strengthened Hurricane Ian has made landfall in South Carolina and is predicted to enter North Carolina soon.  #Florida #NorthCarolina #SouthCarolina #USA #HurricaneIan #Environment https://t.co/LIAALDsxeP - likes: 31 - retweets: 21
#
# page_id= doc_819 - doc_score: 14.516951489181455 - original_tweet: WATCH: Hurricane Ian pushes sea water to the coast of South Carolina. #HurricaneIan #SouthCarolina #Environment https://t.co/ZIGtxaM7WB - likes: 33 - retweets: 13
#
# page_id= doc_3692 - doc_score: 14.396112768757105 - original_tweet: Conditions deterioriating in coastal South Carolina as core of #HurricaneIan approaches.
# * Flash flood warning in Charleston
# * Gusts 40 to 70 mph along the coast
# * Surge near 2' and rising.
# Latest updates: https://t.co/k8yrNg8Ukl
# (Pictured: peak gusts in recent hours) https://t.co/JMJTlXIAwT - likes: 39 - retweets: 17
#
# #HurricaneIan https://t.co/7I24KpRvVB - likes: 21 - retweets: 4
#
# page_id= doc_1435 - doc_score: 10.868201964370863 - original_tweet: Charleston South Carolina flooded. Many of the roads around the city are impassible, and more rain expected. #hurricaneian #charleston #southcarolina #scwx https://t.co/VQNsBEfmEn - likes: 11 - retweets: 6

# %%
#QUERY 3:
print("help people:\n")
our_query3 = input()
our_ranking_docs3,our_ranking_scores3 = our_search(our_query3, index, likes, retweets)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(our_ranking_docs3)))
i=0
for d_id in our_ranking_docs3[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, our_ranking_scores3[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# help people:
#
# help people
#
# ======================
# Top 20 results out of 556 for the searched query:
#
# page_id= doc_2534 - doc_score: 16.961465696074306 - original_tweet: Saw Trump saying, “I hope you can help and help out" and actually thought he was asking for donations for the people of Florida--where he lives--who have been devastated by #HurricaneIan.
#
# Nope--he's asking for supporters to pay his many legal bills.
# https://t.co/2iu0GQVB3W - likes: 74 - retweets: 26
#
# page_id= doc_1202 - doc_score: 16.107045927844027 - original_tweet: Thank you to everyone across the nation and state who want to help the people devastated by #HurricaneIan, just make sure you aren’t being scammed. #FloridaStrong https://t.co/bQ2jJUzPrI - likes: 65 - retweets: 21
#
# page_id= doc_3938 - doc_score: 15.827667031015098 - original_tweet: I can go home, but for so many people, this is home. If you want to help, please donate money to your assistance charity of choice. It’s really the best way to give a hand. @weathernetwork @jwhittalTWN #HurricaneIan #HurricaneFiona https://t.co/ICGNplvfp2 - likes: 117 - retweets: 17
#
# page_id= doc_2944 - doc_score: 15.36288571301277 - original_tweet: Prayers for everyone affected by #HurricaneIan. Thankful for all the churches responding to lend services and helping hands that will show the love of God and point people to Jesus. #powerofprayer #powerofbodyofchrist - likes: 124 - retweets: 12
#
# page_id= doc_3643 - doc_score: 14.587166750167768 - original_tweet: I will try to head back to the coast later today to fly the drone over any areas people are requesting, if you are needing help reaching family or friends in the area, or simply checking your house. DM me with your requests and I'll try my best to fulfill. #ian #HurricaneIan https://t.co/sML0wVH6td - likes: 62 - retweets: 16
#
# page_id= doc_1535 - doc_score: 12.903600325308945 - original_tweet: With emotions running high after #HurricaneIan, fake posts are rampant— including disinformation from grifters preying on the goodwill of people looking to help.
# Here's a 🧵of cyber hygiene tips to avoid donation scams.
# https://t.co/ksaI19q8ir - likes: 16 - retweets: 14
#
# page_id= doc_970 - doc_score: 11.681553069795482 - original_tweet: 201 Republicans just voted against
#
# — Keeping Government Open
#
# — Disaster relief for Jackson, MS, Alaska, New Mexico, Puerto Rico, Florida and other communities hit by #HurricaneIan
#
# — Helping working families pay for higher energy bills
#
# VOTE THEM OUT!
#
# https://t.co/JJ22gVHbbo - likes: 779 - retweets: 362
#
# page_id= doc_1586 - doc_score: 9.973414168180861 - original_tweet: House Democrats are saddened and mourn the loss of life in Florida from #HurricaneIan. We pray for the safety of all in Ian’s path.
#
# We are moving swiftly for those affected — with immediate relief and resources, as well as long term help to rebuild their lives. -NP https://t.co/kZfBAY2oNN - likes: 360 - retweets: 121
#
# page_id= doc_3560 - doc_score: 7.448016588708956 - original_tweet: Join @MLS and @RedCross to help people affected by #HurricaneIan. Your donation will help emergency preparedness, response, and recovery from this disaster: https://t.co/4mohwOmeF0 https://t.co/BUC7TeF5Fq - likes: 7 - retweets: 1
#
# page_id= doc_303 - doc_score: 7.388298817827322 - original_tweet: I came home from #HurricaneIan evacuation and was as relieved to see how Tampa largely escaped its wrath as I was saddened by the destruction elsewhere. But seeing my 11 yr old jump out of the car to help neighbors clean up was a sign that Florida will come together to rebuild. - likes: 165 - retweets: 20

# %%
#QUERY 4:
print("flood damage:\n")
our_query4 = input()
our_ranking_docs4,our_ranking_scores4 = our_search(our_query4, index, likes, retweets)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(our_ranking_docs4)))
i=0
for d_id in our_ranking_docs4[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, our_ranking_scores4[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# flood damage:
#
# flood damage
#
# ======================
# Top 20 results out of 495 for the searched query:
#
# page_id= doc_3743 - doc_score: 23.060783581984037 - original_tweet: . @GovRonDeSantis is requesting quick insurance claim settlements for Floridians.
#
# We don’t need the National Flood Insurance Program (NFIP) fighting w/ private insurance carriers over wind vs. flood damage. I will be watching this closely.
#
# Pray for our state.  #HurricaneIan - likes: 315 - retweets: 85
#
# page_id= doc_1561 - doc_score: 13.321172102797032 - original_tweet: In January of this year, an EF2 tornado caused major damage in Iona (southern Fort Myers). Flooding likely just totaled everything left. Below is a before, after tornado, and after Ian view of the Tropicana 55+ Mobile Home Community. #hurricaneian @SRHelicity @spann https://t.co/Xz0IKOzjmz - likes: 24 - retweets: 11
#
# page_id= doc_1562 - doc_score: 12.535099903039299 - original_tweet: #HurricaneIan, with intense storm surges and rapid flooding, has devasted communities across #Florida. #BlackSky captured imagery showing just a portion of the extensive damage in #FortMyers Beach. Our hearts are with all those affected by this tragedy. https://t.co/v9fk4tbbTa - likes: 20 - retweets: 8
#
# page_id= doc_2995 - doc_score: 12.225476532090836 - original_tweet: You guys… #HurricaneIan Update ☔️
#
# Versailles is a DISASTER! Water flooded the house and we can’t even wrap our heads around the damage. Luckily we’re ok. 💗
#
# Everybody please stay safe! 🙏❤️
# https://t.co/xH9nUqnbaA - likes: 33 - retweets: 5
#
# page_id= doc_581 - doc_score: 10.610741004261026 - original_tweet: Driving across the state from Miami, food truck Monster Burgers helped WCK serve 1,000 meals to families in Cape Coral yesterday. #HurricaneIan damaged a majority of homes here &amp; there is no power or water. For many, this was the first hot meal since the storm. #ChefsForFlorida https://t.co/cMZPnOo0qw - likes: 219 - retweets: 51
#
# page_id= doc_262 - doc_score: 9.354954676800762 - original_tweet: That water rise happened quick here on Myrtle Beach! Damage to the walkway that leads to the Beach!  #HurricaneIan #SCWx https://t.co/4fH8B4lOQl - likes: 74 - retweets: 26
#
# page_id= doc_1613 - doc_score: 9.12933407961282 - original_tweet: Flooding in downtown Charleston South Carolina happening right now due to Hurricane Ian. Many of the roads around the city are impassible, and more rain expected. I will continue covering the flood levels and showing the conditions. #hurricaneian #charleston #southcarolina #scwx https://t.co/62LGGbTHYC - likes: 80 - retweets: 28
#
# (Pictured: peak gusts in recent hours) https://t.co/JMJTlXIAwT - likes: 39 - retweets: 17
#
# page_id= doc_801 - doc_score: 7.091763156057275 - original_tweet: Vehicles stalled out due to flooding in Charleston, SC #HurricaneIan @ryanhallyall @RadarOmega https://t.co/ib8xPlfEaf - likes: 55 - retweets: 8
#
# page_id= doc_3288 - doc_score: 6.872311721540834 - original_tweet: We're still without power &amp; no estimate for restoration so we went to a hotel. There is minor damage to our roof &amp; some flood damage but nothing major. Everything in our fridge &amp; freezer is gone. But it could've been much worse!! #HurricaneIan - likes: 17 - retweets: 0

# %%
#QUERY 5:
print("storm in florida:\n")
our_query5 = input()
our_ranking_docs5,our_ranking_scores5 = our_search(our_query5, index, likes, retweets)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(our_ranking_docs5)))
i=0
for d_id in our_ranking_docs5[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, our_ranking_scores5[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# storm in florida:
#
# storm in florida
#
# ======================
# Top 20 results out of 1163 for the searched query:
#
# page_id= doc_2794 - doc_score: 11.83210091605128 - original_tweet: Storm chaser Reed Timmer (@ReedTimmerAccu) recorded a chaotic scene with flooding storm surge and howling winds in Pine Island, Florida, as he entered the eye of #HurricaneIan on Sept. 28. https://t.co/GGFQFnP47q https://t.co/bY8LFDl5Py - likes: 75 - retweets: 16
#
# page_id= doc_2041 - doc_score: 10.300183160198436 - original_tweet: The damage to southwest and central #Florida is overwhelming after #HurricaneIan made landfall as a Category 4 storm earlier this week. In the wake of the devastation, our U.S. Disaster Relief team will be caring for hurting homeowners in Jesus' Name. https://t.co/G2MBTStteR https://t.co/d9cEOZMc7f - likes: 35 - retweets: 16
#
# page_id= doc_2304 - doc_score: 10.169224507226573 - original_tweet: #HurricaneIan has devastated Florida and our thoughts continue to be with all those affected.
#
# We transported at-risk shelter animals out of harm's way as the storm rapidly approached and remain on standby to help in any way we can. Stay tuned for updates as we know more. 💙 https://t.co/kbP1UsFQqi - likes: 43 - retweets: 13
#
# page_id= doc_2493 - doc_score: 9.816521912269083 - original_tweet: We’re LIVE now covering #HurricaneIan with a team of storm chasers on the ground including @BrandonCopicWx in Charleston County, SC as you see here in the @RadarOmega app: https://t.co/ULcbiIHbYC https://t.co/hxfYezmUNI - likes: 221 - retweets: 92
#
# page_id= doc_868 - doc_score: 9.78097190713766 - original_tweet: .@ENERGY's latest #HurricaneIan update is out now:
#
# • Ian's center is projected to approach #SouthCarolina coast today
# • This morning's projections predict the storm weakening after landfall
# • As of 8 AM, ~2M customers were w/out power in #Florida
# https://t.co/Cv5eKuhKF3 - likes: 25 - retweets: 14
#
# page_id= doc_3458 - doc_score: 8.924082634309553 - original_tweet: We @OfficialOPLive are thinking about everyone impacted by #HurricaneIan.  I imagine during this weekend's shows, we will get a firsthand LIVE look at our first responders in action as they deal with the storm and it's impact on the communities they serve.  #OPLive - likes: 534 - retweets: 29
#
# page_id= doc_581 - doc_score: 8.881819795211953 - original_tweet: Driving across the state from Miami, food truck Monster Burgers helped WCK serve 1,000 meals to families in Cape Coral yesterday. #HurricaneIan damaged a majority of homes here &amp; there is no power or water. For many, this was the first hot meal since the storm. #ChefsForFlorida https://t.co/cMZPnOo0qw - likes: 219 - retweets: 51
# #hurricaneian https://t.co/NTrOfBUSYv - likes: 36 - retweets: 22
#
# page_id= doc_3551 - doc_score: 7.117472454483192 - original_tweet: On September 28th, @NOAA_HurrHunter flew into Category 4 #HurricaneIan just before landfall in #Florida. Despite extreme turbulence, the crew successfully launched the drone, which then completed a 2 hour mission, acquiring critical data to understand these complex storm systems. https://t.co/MTdo2IZBuN - likes: 11 - retweets: 5
#
# page_id= doc_3289 - doc_score: 7.07011675996478 - original_tweet: Significant storm surge beginning in Pawleys Island, SC! No way off the island now! #HurricaneIan #Scwx #ian https://t.co/iqxG8ZIisR - likes: 44 - retweets: 19
#
# page_id= doc_1638 - doc_score: 7.029941911672445 - original_tweet: JUST IN: Hurricane Ian could be the costliest Florida storm since Hurricane Andrew in 1992 as insurers brace for a hit of between $28 billion and $47 billion, according to U.S. property data and analytics company CoreLogic. #HurricaneIan #insurance #Florida #Environment https://t.co/DZ6AQCSp3r - likes: 6 - retweets: 6

# %% [markdown]
# #####BM25

# %%
#Counting the words in each row of preprocessed_tweets column
final_dataset['tw_length']=None
for i in final_dataset.index: 
    final_dataset['tw_length'][i] = len(final_dataset['preprocessed_tweet'][i])

#Computing the Average Length
Total_length = final_dataset['tw_length'].sum() 
N = len(final_dataset['doc_id'])
Lave = round(Total_length/ N)
ld = dict(zip(final_dataset['doc_id'],final_dataset['tw_length']))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
def BM25_rank_documents(terms, docs, index, idf, tf, N, k1, b, Ld, Lave):
    """
    Perform the ranking of the results of a search 
    
    Argument:
    terms -- list of query terms
    docs -- list of documents/tweets, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    N -- Total number of documents
    k1 -- tunning parameter controlling the document term frequency scaling
    b -- tunning parameter controlling the scaling by document term frequency scaling 
    Ld -- lenght of document d
    Lave -- average document lenght in the whole collection

    
    Returns:
    Print the list of ranked documents and documents scores
    """

    # We are interested only on the element of the docVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    doc_vectors = defaultdict(lambda: [0] * len(terms)) # We call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    #query_vector = [0] * len(terms)

    # computing the norm for the query tf
    #query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 

    #query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        #query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]
 
        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):      
            if doc in docs:
                df = len(index[term])
                ld = Ld[doc] 
                idf = np.log(N/df)
                nominator = (k1+1)*tf[term][doc_index]
                denominator = k1*((1-b)+(ld/Lave))+tf[term][doc_index]
                doc_vectors[doc][termIndex] = idf * ((nominator)/(denominator))

    # Calculating the score of each doc 
    # Computing the cosine similarity between queyVector and each docVector:

    doc_scores = [[np.sum(curDocVec), doc] for doc, curDocVec in doc_vectors.items()]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_scores = [x[0] for x in doc_scores]
    if len(doc_scores) == 0:
        print("No results found, try again")
        #query1=input()
        #docs = search_tf_idf(query,index)
    return result_docs, result_scores

# %%
def BM25_search(query, index, N, k1, b, Ld, Lave ):
    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs = [posting[0] for posting in index[term]]
            
            # docs = docs Union term_docs
            docs |= set(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    ranked_docs,ranked_scores = BM25_rank_documents(query, docs, index, idf, tf, N, k1, b, Ld, Lave)
    return ranked_docs, ranked_scores

# %% [markdown]
# ######QUERIES BM25

# %%
#QUERY 1:
print("hurricane ian:\n")
BM25_query1 = input()
BM25_ranking_docs,BM25_ranking_scores = BM25_search(BM25_query1, index, N, 1.5, 1, ld ,Lave)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(BM25_ranking_docs)))
i=0
for d_id in BM25_ranking_docs[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, BM25_ranking_scores[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# hurricane ian:
#
# hurricane ian
#
# ======================
# Top 20 results out of 1095 for the searched query:
#
# page_id= doc_2140 - doc_score: 4.806010837334956 - original_tweet: #hurricaneian
# The perpetual hurricane Ian - likes: 0 - retweets: 0
#
# page_id= doc_1217 - doc_score: 4.806010837334956 - original_tweet: Hurricane Ian on tour😭
# #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_640 - doc_score: 4.146565917688284 - original_tweet: Hurricane Ian before and after #HurricaneIan https://t.co/XZstkI2pN2 - likes: 2 - retweets: 0
#
# page_id= doc_2109 - doc_score: 3.600186493063438 - original_tweet: Praying for everyone impacted in hurricane Ian.#HurricaneIan - likes: 3 - retweets: 1
#
# page_id= doc_634 - doc_score: 3.1300265536195115 - original_tweet: Hurricane IAN #Ian #HurricaneIan #HurricanIan #Huracan #HuracanIan #Hurricane https://t.co/HbllO4Q3vB - likes: 1 - retweets: 0
#
# page_id= doc_2744 - doc_score: 2.776080488894473 - original_tweet: Hope everyone affected by Hurricane Ian is staying safe💖 #HurricaneIan - likes: 0 - retweets: 1
#
# page_id= doc_2455 - doc_score: 2.776080488894473 - original_tweet: Thoughts go out to all affected by hurricane Ian.
# #hurricaneian https://t.co/MGGx4o2gx7 - likes: 0 - retweets: 0
#
# page_id= doc_1519 - doc_score: 2.776080488894473 - original_tweet: Those impacted by Hurricane Ian are in our thoughts and prayers. #hurricaneian https://t.co/trKUBuNKUI - likes: 1 - retweets: 2
#
# page_id= doc_1220 - doc_score: 2.776080488894473 - original_tweet: Thoughts and prayers for all those affected by Hurricane Ian.
# #HurricaneIan https://t.co/YyDIPAljPw - likes: 0 - retweets: 0
#
# page_id= doc_1986 - doc_score: 2.6664045044937463 - original_tweet: Stay home!
#  #DoveHurricaneGuide #HurricaneIan #Hurricane_Ian #HurricaneSeason #Hurricanes https://t.co/7XLjUNmTt8 - likes: 0 - retweets: 0
#
# page_id= doc_495 - doc_score: 2.48827914925109 - original_tweet: Hurricane Ian be like
#
# “You all haven’t had any hurricanes around here lately so I’m just gonna take my time on the East Coast.”
#
# #HurricaneIan #Ian #Hurricane - likes: 0 - retweets: 0
#
# page_id= doc_3915 - doc_score: 2.46445030936912 - original_tweet: FOX donated $1 million for Hurricane Ian relief efforts.
# #HurricaneIan - likes: 3 - retweets: 0
#
# page_id= doc_2877 - doc_score: 2.46445030936912 - original_tweet: Hurricane Ian From Cuba through Florida to South Carolina.
# #HurricaneIan https://t.co/7TypUjrtlW - likes: 0 - retweets: 0
#
# page_id= doc_2786 - doc_score: 2.46445030936912 - original_tweet: Some sloppy landscaping by Hurricane Ian! #HurricaneIan #dougmilesmedia #SarasotaCounty https://t.co/JUORfJoGdF - likes: 1 - retweets: 0
#
# page_id= doc_2110 - doc_score: 2.46445030936912 - original_tweet: Hurricane Ian cant move me💀 #hurricaneian #gaming #streamer https://t.co/D6MMLOvDSb - likes: 1 - retweets: 0
#
# page_id= doc_1171 - doc_score: 2.46445030936912 - original_tweet: #Hurricane #Ian #HurricaneIan
# updates coming at the top of the hour. https://t.co/rBDGUcrZyU - likes: 5 - retweets: 0
#
# page_id= doc_807 - doc_score: 2.4434406004434055 - original_tweet: Ian is predicted to spare Atlanta
#
# #HurricaneIan #Hurricane #Ian #AtlantaNews #ATL https://t.co/Zib8NtmG2k - likes: 1 - retweets: 0
#
# page_id= doc_3526 - doc_score: 2.437157764163297 - original_tweet: Hurricane Ian Relief gonna be a long day @xufn #HurricaneIan #Hurricane https://t.co/EzBzHMfksr - likes: 1 - retweets: 0
#
# page_id= doc_469 - doc_score: 2.41603304150363 - original_tweet: My damn power out because of Ian #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_2537 - doc_score: 2.3899777958313257 - original_tweet: PRAY 🙏 FOR ALL WHO SUFFERED FROM THE HURRICANE #HurricaneIan - likes: 0 - retweets: 0

# %%
#QUERY 2:
print("south carolina:\n")
BM25_query2 = input()
BM25_ranking_docs2,BM25_ranking_scores2 = BM25_search(BM25_query2, index, N, 1.5, 1, ld ,Lave)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(BM25_ranking_docs2)))
i=0
for d_id in BM25_ranking_docs2[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, BM25_ranking_scores2[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# south carolina:
#
# south carolina
#
# ======================
# Top 20 results out of 358 for the searched query:
#
# page_id= doc_174 - doc_score: 7.931362905024203 - original_tweet: South Carolina #HurricaneIan here we go - likes: 1 - retweets: 0
#
# page_id= doc_254 - doc_score: 6.843080512283574 - original_tweet: South Carolina #HurricaneIan https://t.co/yTA4dFUC2V - likes: 0 - retweets: 0
#
# page_id= doc_480 - doc_score: 5.941390181734711 - original_tweet: South Carolina friends, you OK so far?? #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_48 - doc_score: 5.941390181734711 - original_tweet: Sending love and prayers to South Carolina #HurricaneIan 🙏 ❤️ - likes: 0 - retweets: 0
#
# page_id= doc_1401 - doc_score: 5.941390181734711 - original_tweet: #hurricaneian won't go away prayers for South Carolina - likes: 1 - retweets: 0
#
# page_id= doc_2874 - doc_score: 5.197737826108093 - original_tweet: From .@ABCNews4 in Charleston, South Carolina - #HurricaneIan https://t.co/TLCRoQ3VvD - likes: 0 - retweets: 0
#
# page_id= doc_2834 - doc_score: 5.197737826108093 - original_tweet: from .@ABCNews4 in Charleston, South Carolina - #HurricaneIan https://t.co/nbxQROQSKW - likes: 0 - retweets: 0
#
# page_id= doc_2505 - doc_score: 5.197737826108093 - original_tweet: ⚠️ #HurricaneIan about to make landfall on South Carolina! https://t.co/X61NAwpsx6 - likes: 2 - retweets: 1
#
# page_id= doc_249 - doc_score: 5.197737826108093 - original_tweet: #HurricaneIan makes landfall in South Carolina... https://t.co/vKik1OyOgQ - likes: 1 - retweets: 0
#
# page_id= doc_1078 - doc_score: 5.197737826108093 - original_tweet: Now South Carolina is getting hammered by #HurricaneIan 😫 https://t.co/fnGkXXhKM8 - likes: 0 - retweets: 0
#
# page_id= doc_1035 - doc_score: 5.197737826108093 - original_tweet: GET VACCINATED SOUTH CAROLINA, #HurricaneIan is coming! 🤦‍♂️ #FJB - likes: 0 - retweets: 0
#
# page_id= doc_595 - doc_score: 4.5813674908791135 - original_tweet: #HurricaneIan headed towards Charleston, South Carolina https://t.co/Pm6W0pAeYB - likes: 0 - retweets: 0
#
# page_id= doc_3372 - doc_score: 4.5813674908791135 - original_tweet: Be safe all in South Carolina
# and all around too during
# this time.
# Prayers are with yall🙏🙏
# #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_2197 - doc_score: 4.5813674908791135 - original_tweet: Storm Serge in South Carolina due to #HurricaneIan https://t.co/48E9hOwHyP - likes: 0 - retweets: 0
#
# page_id= doc_1285 - doc_score: 4.5813674908791135 - original_tweet: The view as #HurricaneIan roars ashore in South Carolina https://t.co/RybeeJsyjj - likes: 3 - retweets: 0
#
# page_id= doc_701 - doc_score: 4.495928412505917 - original_tweet: Hunker Down, #Carolinas #HurricaneIan. - likes: 0 - retweets: 0
#
# page_id= doc_493 - doc_score: 4.4311846044573056 - original_tweet: Just south of Myrtle Beach in South Carolina. #HurricaneIan #Ian #ScWx https://t.co/ErHr5X5cQQ - likes: 1 - retweets: 0
#
# page_id= doc_964 - doc_score: 4.067083996806927 - original_tweet: Wishing safety and security for all the queens in South Carolina!
#
# #HurricaneIan https://t.co/6dBcjaA0Hf - likes: 0 - retweets: 0
#
# page_id= doc_621 - doc_score: 4.067083996806927 - original_tweet: @ryanhallyall West Ashley, South Carolina #Ian #HurricaneIan https://t.co/tWouToidQf - likes: 0 - retweets: 0
#
# page_id= doc_614 - doc_score: 4.067083996806927 - original_tweet: Roof has blown off of a hotel in Charleston, South Carolina #HurricaneIan https://t.co/f1PkB4mwD4 - likes: 2 - retweets: 1

# %%
#QUERY 3:
print("help people:\n")
BM25_query3 = input()
BM25_ranking_docs3,BM25_ranking_scores3 = BM25_search(BM25_query3, index, N, 1.5, 1, ld ,Lave)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(BM25_ranking_docs3)))
i=0
for d_id in BM25_ranking_docs3[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, BM25_ranking_scores3[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# help people:
#
# help people
#
# ======================
# Top 20 results out of 556 for the searched query:
#
# page_id= doc_191 - doc_score: 3.9865987582590328 - original_tweet: @SenGaryPeters @SenStabenow
# Just wondering why you are quiet about the helping the people in Florida and SC after the #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3428 - doc_score: 3.79650493860049 - original_tweet: Why people hurt people’s feelings? #PonniyinSelvan #HurricaneIan #CovidIsNotOver - likes: 0 - retweets: 0
#
# page_id= doc_2688 - doc_score: 3.6849380106240917 - original_tweet: Thinking about the people who have lost anything to #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_898 - doc_score: 3.5641522955915836 - original_tweet: @DonaldJTrumpJr Don't even TRY to open a charity to "help the people of Florida recover from #HurricaneIan..." 😂😂😂 - likes: 1 - retweets: 0
#
# page_id= doc_2027 - doc_score: 3.5352673151211267 - original_tweet: @KEYCNewsNow Thanks for sharing how the Red Cross is helping those affected by #hurricaneian and raising awareness on how people can help! - likes: 0 - retweets: 0
#
# page_id= doc_3579 - doc_score: 3.2069822899349787 - original_tweet: @GovRonDeSantis maybe you should have saved that illegal shipping of people money to help the citizens of Florida #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_1458 - doc_score: 3.1142392580459175 - original_tweet: Want to help those affected by #HurricaneIan? Here's how to help!
# https://t.co/vmA6kBgGER - likes: 0 - retweets: 0
#
# page_id= doc_477 - doc_score: 3.0227218986264512 - original_tweet: Help is on the way #HurricaneIan https://t.co/MnGoOB2Gzg - likes: 0 - retweets: 0
#
# page_id= doc_584 - doc_score: 2.9027585437207053 - original_tweet: Join FOX in our support of @RedCross relief efforts and help people affected by #HurricaneIan:  https://t.co/rg8EFwC0NC - likes: 2 - retweets: 1
#
# page_id= doc_2726 - doc_score: 2.9027585437207053 - original_tweet: Join Fox in our support of @RedCross relief efforts and help people affected by #HurricaneIan:  https://t.co/VaepU9Kkt9 - likes: 0 - retweets: 1
#
# page_id= doc_2314 - doc_score: 2.798935603680742 - original_tweet: So many people are struggling in the aftermath of #hurricaneian 💔 https://t.co/nOafCbxKUA - likes: 0 - retweets: 0
#
# page_id= doc_1300 - doc_score: 2.789059120103347 - original_tweet: It has been so encouraging how many lawyers &amp; people I’ve seen on @Twitter offering to help with #HurricaneIan! We are all better when we help others! https://t.co/1Mfh8Orksy - likes: 1 - retweets: 0
#
# page_id= doc_812 - doc_score: 2.7718202643464402 - original_tweet: Looking for organizations that are providing help to #HurricaneIan victims in Central Florida. We're trying to connect groups with people who need help. Know of any groups out there that people can contact? - likes: 1 - retweets: 0
#
# page_id= doc_947 - doc_score: 2.624427723504984 - original_tweet: Here’s how you can help those impacted by #HurricaneIan: https://t.co/c1Fucam41z @KSHB41 - likes: 0 - retweets: 0
#
# page_id= doc_3682 - doc_score: 2.480294550838848 - original_tweet: Good morning lovelies. Yesterday my employer sent an email about donations to help Florida #HurricaneIan victims. But I wanna hear from YOU, how can people help? The theme parks will be ok, I’m concerned about the PEOPLE! What can people do to help? https://t.co/ERiJukIPVN - likes: 3 - retweets: 0
#
# page_id= doc_3604 - doc_score: 2.4670256586158925 - original_tweet: DO NOT leave your pets behind in a storm, people. #HurricaneIan https://t.co/9xHwIPz6Ko - likes: 1 - retweets: 0
#
# page_id= doc_3306 - doc_score: 2.4670256586158925 - original_tweet: What the hell is wrong with these people?
#
# vote him out Florida!!
#
# #HurricaneIan https://t.co/wnhFoUg4m8 - likes: 2 - retweets: 0
#
# page_id= doc_2561 - doc_score: 2.4670256586158925 - original_tweet: I wonder how many people died trying to TikTok during the hurricane #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3172 - doc_score: 2.4188055918601985 - original_tweet: Neighbors helping neighbors #hurricaneian https://t.co/Ci1dqwkCo7 - likes: 7 - retweets: 3
#
# page_id= doc_2817 - doc_score: 2.4153265726282784 - original_tweet: #HurricaneIan has impacted millions of people, namely in Florida and Cuba. Here are organizations that you can donate to or support to help those in need. https://t.co/ZegLq6UtXn - likes: 1 - retweets: 1

# %%
#QUERY 4:
print("flood damage:\n")
BM25_query4 = input()
BM25_ranking_docs4,BM25_ranking_scores4 = BM25_search(BM25_query4, index, N, 1.5, 1, ld ,Lave)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(BM25_ranking_docs4)))
i=0
for d_id in BM25_ranking_docs4[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, BM25_ranking_scores4[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# flood damage:
#
# flood damage
#
# ======================
# Top 20 results out of 495 for the searched query:
#
# page_id= doc_857 - doc_score: 2.9447822765642053 - original_tweet: Flooding outside Iona. #HurricaneIan https://t.co/ZIMzpJE2ge - likes: 0 - retweets: 0
#
# page_id= doc_3488 - doc_score: 2.9447822765642053 - original_tweet: Power is staring to flicker on and off and the pool is about to flood over #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_1672 - doc_score: 2.9447822765642053 - original_tweet: Edgewater Florida Flooding. #HurricaneIan https://t.co/eK3lFQ0yLq - likes: 4 - retweets: 0
#
# page_id= doc_1389 - doc_score: 2.9447822765642053 - original_tweet: Intense flooding on so many streets in my town. #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3735 - doc_score: 2.798935603680742 - original_tweet: Satellite imagery of the damage https://t.co/NggqAbpfnT
#
# #hurricaneian #sanibel - likes: 1 - retweets: 0
#
# page_id= doc_3658 - doc_score: 2.798935603680742 - original_tweet: We can’t get into plantation . #venicefl #HurricaneIan #Damage https://t.co/h7k23cMVLk - likes: 1 - retweets: 0
#
# page_id= doc_3409 - doc_score: 2.798935603680742 - original_tweet: #wellness check #HurricaneIan #Damage #venicefl https://t.co/7ZPtL5Hj8c - likes: 2 - retweets: 1
#
# page_id= doc_3068 - doc_score: 2.798935603680742 - original_tweet: #wellness check #HurricaneIan #venicefl #damage https://t.co/8i6n8QhzEV - likes: 0 - retweets: 0
#
# page_id= doc_1555 - doc_score: 2.798935603680742 - original_tweet: The damage from #HurricaneIan is “catastrophic” and historic.
# https://t.co/OY323JCzyQ 02 - likes: 2 - retweets: 3
#
# page_id= doc_3471 - doc_score: 2.5761994685360845 - original_tweet: #HurricaneIan Flooded Angelo Dawkins' Home
#
# https://t.co/DFqk1X1dgZ - likes: 73 - retweets: 8
#
# page_id= doc_3470 - doc_score: 2.5761994685360845 - original_tweet: #HurricaneIan Flooded Angelo Dawkins' Home
#
# https://t.co/XKve9Y21oo - likes: 3 - retweets: 0
#
# page_id= doc_338 - doc_score: 2.5761994685360845 - original_tweet: Flooding in #ORF from High Tide during #HurricaneIan https://t.co/wULmAnZtyd - likes: 0 - retweets: 0
#
# page_id= doc_3184 - doc_score: 2.5761994685360845 - original_tweet: #HurricaneIan Flooded Angelo Dawkins' Home
#
# https://t.co/FYXabtuMZy - likes: 7 - retweets: 8
#
# page_id= doc_3071 - doc_score: 2.5761994685360845 - original_tweet: How to Wash Clothes Contaminated From a Flood #HurricaneIan  https://t.co/V3LXtZZDck - likes: 2 - retweets: 1
#
# page_id= doc_2782 - doc_score: 2.5761994685360845 - original_tweet: Streets are starting to flood. #HurricaneIan #Charleston https://t.co/GgIvRbdlpQ - likes: 6 - retweets: 0
#
# page_id= doc_1083 - doc_score: 2.5761994685360845 - original_tweet: Flooding now a major concern. This is in #GardenCity #HurricaneIan https://t.co/ZTSyRGRzel - likes: 3 - retweets: 2
#
# page_id= doc_1044 - doc_score: 2.5761994685360845 - original_tweet: Survived the hurricane, but now we’re flooded in #HurricaneIan #Orlando https://t.co/6i0QpYp9At - likes: 0 - retweets: 0
#
# page_id= doc_3441 - doc_score: 2.4670256586158925 - original_tweet: @seanferrick out and about today. Minimal damage, we were very lucky. #HurricaneIan https://t.co/1ZFQJHEZ5T - likes: 0 - retweets: 0
#
# page_id= doc_3422 - doc_score: 2.4670256586158925 - original_tweet: Important context to understanding the damage done by #HurricaneIan
#
# https://t.co/cCH7Dxill5 - likes: 0 - retweets: 0
#
# page_id= doc_1374 - doc_score: 2.360921390574982 - original_tweet: just had an advert pop up for help #floods in pakistan. how about helping the floods for #miami and #Hurricane_Ian #hurricaneian - likes: 0 - retweets: 0

# %%
#QUERY 5:
print("storm in florida:\n")
BM25_query5 = input()
BM25_ranking_docs5,BM25_ranking_scores5 = BM25_search(BM25_query5, index, N, 1.5, 1, ld ,Lave)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(BM25_ranking_docs5)))
i=0
for d_id in BM25_ranking_docs5[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} - likes: {} - retweets: {}\n".format(d_id, BM25_ranking_scores5[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# storm in florida:
#
# storm in florida
#
# ======================
# Top 20 results out of 1163 for the searched query:
#
# page_id= doc_3475 - doc_score: 3.127147970679615 - original_tweet: Yesterday after the storm #HurricaneIan https://t.co/igI6Z0mvGp - likes: 0 - retweets: 0
#
# page_id= doc_3311 - doc_score: 3.127147970679615 - original_tweet: Doing good here but the storm is picking up for sure. #HurricaneIan - likes: 3 - retweets: 0
#
# page_id= doc_132 - doc_score: 2.7150939136952186 - original_tweet: #HurricaneIan is here, a beautiful calm before the storm https://t.co/axB9kjuLax - likes: 1 - retweets: 0
#
# page_id= doc_1172 - doc_score: 2.7150939136952186 - original_tweet: Storm cleanup! #jchsramfam #hurricaneian https://t.co/X9tpgc1kKR - likes: 1 - retweets: 0
#
# page_id= doc_470 - doc_score: 2.2593069866886726 - original_tweet: Thank God. 😢🙏🏾 #HurricaneIan
# #Florida - likes: 1 - retweets: 0
#
# page_id= doc_1676 - doc_score: 2.1968477838177103 - original_tweet: Florida’s ‘deadliest storm’ challenges some #seniorliving providers; others step in to help. #HurricaneIan
# https://t.co/rDLvZwhMod - likes: 0 - retweets: 0
#
# page_id= doc_92 - doc_score: 2.093591333073371 - original_tweet: Wow! Storm surge from #Ian #scwx #HurricaneIan https://t.co/DHZSscNZcn - likes: 0 - retweets: 0
#
# page_id= doc_888 - doc_score: 2.093591333073371 - original_tweet: Storm surge from #HurricaneIan in Garden City, SC https://t.co/3H7BAElstU - likes: 1 - retweets: 1
#
# page_id= doc_823 - doc_score: 2.093591333073371 - original_tweet: Storm surge flooding in Myrtle Beach. #HurricaneIan https://t.co/8Pp9qUl8Vz - likes: 5 - retweets: 2
#
# page_id= doc_7 - doc_score: 2.093591333073371 - original_tweet: Storm surge issues in Georgetown, SC #HurricaneIan https://t.co/qWs0XJzGMx - likes: 0 - retweets: 0
#
# page_id= doc_3820 - doc_score: 2.093591333073371 - original_tweet: I am in Southern Virginia and we are definitely experiencing Tropical Storm conditions. #HurricaneIan - likes: 0 - retweets: 0
#
# page_id= doc_3604 - doc_score: 2.093591333073371 - original_tweet: DO NOT leave your pets behind in a storm, people. #HurricaneIan https://t.co/9xHwIPz6Ko - likes: 1 - retweets: 0
#
# page_id= doc_2197 - doc_score: 2.093591333073371 - original_tweet: Storm Serge in South Carolina due to #HurricaneIan https://t.co/48E9hOwHyP - likes: 0 - retweets: 0
#
# page_id= doc_1615 - doc_score: 2.0083197355075035 - original_tweet: Praying for everyone down in my community in Florida. #Naples #Florida #HurricaneIan - likes: 1 - retweets: 0
#
# page_id= doc_3848 - doc_score: 1.949301752676289 - original_tweet: Be careful #Florida!
# #hurricaneian https://t.co/ghPKhAcjbN - likes: 0 - retweets: 0
#
# page_id= doc_2291 - doc_score: 1.949301752676289 - original_tweet: Praying for my family and friends in Florida #hurricaneian - likes: 0 - retweets: 0
#
# page_id= doc_1745 - doc_score: 1.8910052123468768 - original_tweet: More than 21 dead in #Florida after #HurricaneIan; growing storm about to make second landfall in #SouthCarolina - South Florida Sun Sentinel https://t.co/OYrtDF9UT9 - likes: 1 - retweets: 0
#
# page_id= doc_1714 - doc_score: 1.868351411183438 - original_tweet: VDOT completing storm preparations in advance of Tropical Storm Ian's arrival https://t.co/7WU3pFba3s #ian #hurricaneian - likes: 0 - retweets: 0
#
# page_id= doc_3827 - doc_score: 1.8585742845445676 - original_tweet: This gave me a whole new perspective on what storm surge is. #HurricaneIan https://t.co/AKDrLuLKjL - likes: 0 - retweets: 0
#
# page_id= doc_3276 - doc_score: 1.8585742845445676 - original_tweet: When the air temp is below 60°F, should we really call it a "Tropical Storm"?
#
# #HurricaneIan - likes: 2 - retweets: 0

# %% [markdown]
# ####Part 2

# %% [markdown]
# ##### Word2_vec + cosine similarity

# %%
from gensim.models import Word2Vec
tweets = []
for i, tweet in final_dataset.iterrows():
    tweets.append((tweet['preprocessed_tweet']))
model = Word2Vec(tweets, min_count = 1, vector_size = 100, window = 5) #tota la coleccio de paraules de tots els tweets


tweet2vec = {}
for i, tweet in final_dataset.iterrows():
    doc_vec = [model.wv[term] for term in (tweet['preprocessed_tweet'])]
    tweet2vec[tweet['doc_id']] = np.mean(doc_vec, axis=0) #per cada tweet fem una llista amb tots les vectors, fem la mitja de totes les paraules que te aquell tweett

# %%
def word2vec_rank(query, docs, tweet2vec, model):
    """
    Rank documents based on the cosine similarity with the query.
    
    Argument:
    query -- list of terms in the query
    docs -- documents having the query terms
    tweet2vec -- dictionary having each document tweet2vec representation
    model -- word2vec model
    
    Returns:
    list of ranked documents and scores
    """

    #Computing the query_vector
    query_vector = np.array([model.wv[term] for term in query if term in model.wv.key_to_index])
    #Computing the query_vector average
    query_vector = np.mean(query_vector, axis=0)

    # Calculating the score of each doc 
    # Computing the cosine similarity between queyVector and each docVector:
    doc_scores=[[np.dot(doc_vec, query_vector), doc] for doc, doc_vec in tweet2vec.items() if doc in docs]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_scores = [x[0] for x in doc_scores]
    
    if len(doc_scores) == 0:
        print("No results found, try again")
        #query1=input()
        #docs = search_tf_idf(query,index)
    return result_docs, result_scores

# %%
def word2vec_search(query, tweet2vec, model, index):

    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    
    query = build_terms(query)
    docs = set()

    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs=[posting[0] for posting in index[term]]
            # docs = docs Union term_docs
            docs = docs.union(term_docs)
        except:
            # Term is not in index
            pass
    docs = list(docs)
    ranked_docs,ranked_scores = word2vec_rank(query, docs, tweet2vec, model)
    return ranked_docs, ranked_scores

# %% [markdown]
# ######QUERIES WORD2_VEC + COSINE SIMILARITY

# %%
#QUERY 1:
print("hurricane ian:\n")
word2vec_query1 = input()
word2vec_ranking_docs,word2vec_ranking_scores = word2vec_search(word2vec_query1,tweet2vec, model, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(word2vec_ranking_docs)))
i=0
for d_id in word2vec_ranking_docs[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} -  likes: {} - retweets: {}\n".format(d_id, word2vec_ranking_scores[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# hurricane ian:
#
# hurricane ian
#
# ======================
# Top 20 results out of 1095 for the searched query:
#
# page_id= doc_640 - doc_score: 47.054290771484375 - original_tweet: Hurricane Ian before and after #HurricaneIan https://t.co/XZstkI2pN2 -  likes: 2 - retweets: 0
#
# page_id= doc_1163 - doc_score: 43.35344314575195 - original_tweet: Ian is making landfall again. #HurricaneIan https://t.co/NCxy8gqWLD -  likes: 2 - retweets: 1
#
# page_id= doc_2877 - doc_score: 42.77740478515625 - original_tweet: Hurricane Ian From Cuba through Florida to South Carolina.
# #HurricaneIan https://t.co/7TypUjrtlW -  likes: 0 - retweets: 0
#
# page_id= doc_902 - doc_score: 41.802738189697266 - original_tweet: #SouthCarolina right now be like...
#
# #HurricaneIan
# #Ian https://t.co/VLxhRLiWRe -  likes: 1 - retweets: 0
#
# page_id= doc_2109 - doc_score: 41.258575439453125 - original_tweet: Praying for everyone impacted in hurricane Ian.#HurricaneIan -  likes: 3 - retweets: 1
#
# page_id= doc_2744 - doc_score: 41.23740005493164 - original_tweet: Hope everyone affected by Hurricane Ian is staying safe💖 #HurricaneIan -  likes: 0 - retweets: 1
#
# page_id= doc_2455 - doc_score: 41.21717834472656 - original_tweet: Thoughts go out to all affected by hurricane Ian.
# #hurricaneian https://t.co/MGGx4o2gx7 -  likes: 0 - retweets: 0
#
# page_id= doc_1217 - doc_score: 40.63533401489258 - original_tweet: Hurricane Ian on tour😭
# #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_111 - doc_score: 40.547611236572266 - original_tweet: Florida’s Long Road To Recovery
# #florida #hurricaneian #hurricane #ian
# https://t.co/zcE3Yv79bg -  likes: 0 - retweets: 1
#
# page_id= doc_2140 - doc_score: 39.875877380371094 - original_tweet: #hurricaneian
# The perpetual hurricane Ian -  likes: 0 - retweets: 0
#
# page_id= doc_469 - doc_score: 39.87556076049805 - original_tweet: My damn power out because of Ian #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_2183 - doc_score: 39.39108657836914 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/jRNPo8JHFr https://t.co/M1iBwcpNWi -  likes: 0 - retweets: 0
#
# page_id= doc_2108 - doc_score: 39.386016845703125 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/nwZj6hUSQU https://t.co/5SUmNrY8TM -  likes: 0 - retweets: 0
#
# page_id= doc_1993 - doc_score: 39.37544250488281 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/X2lzTVL9qV https://t.co/XU87XaUiLQ -  likes: 0 - retweets: 0
#
# page_id= doc_1166 - doc_score: 39.35177230834961 - original_tweet: Getting back to normal after Ian. What's on and what's not? #hurricaneian #ian https://t.co/Ha1omEibgB https://t.co/CiH4GCelMr -  likes: 0 - retweets: 0
#
# page_id= doc_493 - doc_score: 39.34858703613281 - original_tweet: Just south of Myrtle Beach in South Carolina. #HurricaneIan #Ian #ScWx https://t.co/ErHr5X5cQQ -  likes: 1 - retweets: 0
#
# page_id= doc_2051 - doc_score: 39.32768630981445 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/ZpWXIZ1hIV https://t.co/Tq8ktg46yf -  likes: 0 - retweets: 0
#
# page_id= doc_3766 - doc_score: 39.28455352783203 - original_tweet: Recovery assistance for Florida businesses: https://t.co/UxTI2fkrJf  #ian #hurricaneian https://t.co/PPhgekcNd2 -  likes: 0 - retweets: 0
#
# page_id= doc_2918 - doc_score: 39.28411865234375 - original_tweet: Hurricane Ian begins to make landfall in South Carolina https://t.co/4tMbjEiAJ5 #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_1519 - doc_score: 39.20098876953125 - original_tweet: Those impacted by Hurricane Ian are in our thoughts and prayers. #hurricaneian https://t.co/trKUBuNKUI -  likes: 1 - retweets: 2

# %%
#QUERY 2:
print("south carolina:\n")
word2vec_query2 = input()
word2vec_ranking_docs2,word2vec_ranking_scores2 = word2vec_search(word2vec_query2,tweet2vec, model, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(word2vec_ranking_docs2)))
i=0
for d_id in word2vec_ranking_docs2[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} -  likes: {} - retweets: {}\n".format(d_id, word2vec_ranking_scores2[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# south carolina:
#
# south carolina
#
# ======================
# Top 20 results out of 358 for the searched query:
#
# page_id= doc_174 - doc_score: 35.081485748291016 - original_tweet: South Carolina #HurricaneIan here we go -  likes: 1 - retweets: 0
#
# page_id= doc_254 - doc_score: 33.366905212402344 - original_tweet: South Carolina #HurricaneIan https://t.co/yTA4dFUC2V -  likes: 0 - retweets: 0
#
# page_id= doc_2877 - doc_score: 33.206207275390625 - original_tweet: Hurricane Ian From Cuba through Florida to South Carolina.
# #HurricaneIan https://t.co/7TypUjrtlW -  likes: 0 - retweets: 0
#
# page_id= doc_2505 - doc_score: 31.92981719970703 - original_tweet: ⚠️ #HurricaneIan about to make landfall on South Carolina! https://t.co/X61NAwpsx6 -  likes: 2 - retweets: 1
#
# page_id= doc_249 - doc_score: 31.907285690307617 - original_tweet: #HurricaneIan makes landfall in South Carolina... https://t.co/vKik1OyOgQ -  likes: 1 - retweets: 0
#
# page_id= doc_2545 - doc_score: 31.055496215820312 - original_tweet: Businesses that are open in south Florida. #HurricaneIan https://t.co/RuqvE2Yhvv -  likes: 0 - retweets: 1
#
# page_id= doc_493 - doc_score: 30.606416702270508 - original_tweet: Just south of Myrtle Beach in South Carolina. #HurricaneIan #Ian #ScWx https://t.co/ErHr5X5cQQ -  likes: 1 - retweets: 0
#
# page_id= doc_2918 - doc_score: 30.544185638427734 - original_tweet: Hurricane Ian begins to make landfall in South Carolina https://t.co/4tMbjEiAJ5 #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_856 - doc_score: 30.210399627685547 - original_tweet: Ian making landfall once again in the Carolinas #ncwx #scwx #HurricaneIan 🙏🏼 https://t.co/v51yOfIwmA -  likes: 0 - retweets: 1
#
# page_id= doc_636 - doc_score: 30.070642471313477 - original_tweet: #HurricaneIan about to make landfall in South Carolina as a category 1 hurricane. https://t.co/jxPSV3XJaL -  likes: 0 - retweets: 0
#
# page_id= doc_3503 - doc_score: 29.93283462524414 - original_tweet: . #HurricaneIan is making its way into the Carolinas as Florida works to survey the damage.
#
# https://t.co/m3ABKeOxBG -  likes: 0 - retweets: 0
#
# page_id= doc_2204 - doc_score: 29.867752075195312 - original_tweet: Get the latest on #HurricaneIan as it nears South Carolina. https://t.co/wZnjheX8UQ https://t.co/dFK8queEEq -  likes: 0 - retweets: 0
#
# page_id= doc_345 - doc_score: 29.86493492126465 - original_tweet: NEW: #HurricaneIan has made landfall once again, this time in South Carolina: https://t.co/vIAw3QjFwn -  likes: 0 - retweets: 0
#
# page_id= doc_255 - doc_score: 29.71381378173828 - original_tweet: #BREAKING | #HurricaneIan makes landfall in US' South Carolina https://t.co/T8f7Gq5jnb -  likes: 8 - retweets: 1
#
# page_id= doc_919 - doc_score: 29.333452224731445 - original_tweet: #LIVE: We're continuing to follow Hurricane Ian's impacts around Charleston and South Carolina. #chswx #scwx #HurricaneIan https://t.co/pr9yuksJcS -  likes: 1 - retweets: 1
#
# page_id= doc_1078 - doc_score: 28.87436866760254 - original_tweet: Now South Carolina is getting hammered by #HurricaneIan 😫 https://t.co/fnGkXXhKM8 -  likes: 0 - retweets: 0
#
# page_id= doc_152 - doc_score: 28.8436222076416 - original_tweet: Praying for the people in one of the many places I call home, South Carolina 🤍 #HurricaneIan -  likes: 1 - retweets: 0
#
# page_id= doc_1401 - doc_score: 28.76612091064453 - original_tweet: #hurricaneian won't go away prayers for South Carolina -  likes: 1 - retweets: 0
#
# page_id= doc_2484 - doc_score: 28.68899917602539 - original_tweet: Floods trap many in Florida as Ian heads to South Carolina
# https://t.co/zmUfHC9egM #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_2874 - doc_score: 28.578466415405273 - original_tweet: From .@ABCNews4 in Charleston, South Carolina - #HurricaneIan https://t.co/TLCRoQ3VvD -  likes: 0 - retweets: 0

# %%
#QUERY 3:
print("help people:\n")
word2vec_query3 = input()
word2vec_ranking_docs3,word2vec_ranking_scores3 = word2vec_search(word2vec_query3,tweet2vec, model, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(word2vec_ranking_docs3)))
i=0
for d_id in word2vec_ranking_docs3[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} -  likes: {} - retweets: {}\n".format(d_id, word2vec_ranking_scores3[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# help people:
#
# help people
#
# ======================
# Top 20 results out of 556 for the searched query:
#
# page_id= doc_477 - doc_score: 39.82735824584961 - original_tweet: Help is on the way #HurricaneIan https://t.co/MnGoOB2Gzg -  likes: 0 - retweets: 0
#
# page_id= doc_1458 - doc_score: 37.33622360229492 - original_tweet: Want to help those affected by #HurricaneIan? Here's how to help!
# https://t.co/vmA6kBgGER -  likes: 0 - retweets: 0
#
# page_id= doc_2183 - doc_score: 36.44008255004883 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/jRNPo8JHFr https://t.co/M1iBwcpNWi -  likes: 0 - retweets: 0
#
# page_id= doc_2108 - doc_score: 36.43523406982422 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/nwZj6hUSQU https://t.co/5SUmNrY8TM -  likes: 0 - retweets: 0
#
# page_id= doc_1993 - doc_score: 36.42539978027344 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/X2lzTVL9qV https://t.co/XU87XaUiLQ -  likes: 0 - retweets: 0
#
# page_id= doc_2051 - doc_score: 36.38114929199219 - original_tweet: Here's how you can help those affected by Hurricane Ian in Florida via/ @USATODAY #HurricaneIan https://t.co/ZpWXIZ1hIV https://t.co/Tq8ktg46yf -  likes: 0 - retweets: 0
#
# page_id= doc_1430 - doc_score: 36.020103454589844 - original_tweet: List of all the ways to help those affected by #HurricaneIan. ⏬️⏬️⏬️ https://t.co/cM4AehS3ir -  likes: 2 - retweets: 1
#
# page_id= doc_3956 - doc_score: 35.11829376220703 - original_tweet: Here's a great way to help those impacted by #HurricaneIan https://t.co/I1Q8S9cfAk -  likes: 1 - retweets: 0
#
# page_id= doc_947 - doc_score: 34.46323013305664 - original_tweet: Here’s how you can help those impacted by #HurricaneIan: https://t.co/c1Fucam41z @KSHB41 -  likes: 0 - retweets: 0
#
# page_id= doc_152 - doc_score: 34.40220642089844 - original_tweet: Praying for the people in one of the many places I call home, South Carolina 🤍 #HurricaneIan -  likes: 1 - retweets: 0
#
# page_id= doc_2072 - doc_score: 33.837806701660156 - original_tweet: Donate to the Florida Disaster Fund - Volunteer Florida to help Floridians recover from #hurricaneian  https://t.co/Ud4BNM81EJ -  likes: 1 - retweets: 0
#
# page_id= doc_321 - doc_score: 33.83091735839844 - original_tweet: A list of ways you can help the victims of #HurricaneIan
# https://t.co/D77WKvhKhI -  likes: 0 - retweets: 0
#
# page_id= doc_2142 - doc_score: 33.37736511230469 - original_tweet: Our hearts go out to all affected by the devastation of #HurricaneIan. 💛 If you’re looking for ways to help those impacted by the hurricane, please check out this helpful article: https://t.co/Z4OxioX2qX -  likes: 0 - retweets: 0
#
# page_id= doc_1758 - doc_score: 33.361839294433594 - original_tweet: Our thoughts &amp; prayers are with the countless people &amp; communities of Florida that have been impacted by Hurricane Ian. 🙏
# .
# .
# .
# #engelvoelkers #evamericas #hurricane #hurricaneian #florida #support #community https://t.co/4nxv8wSKnG -  likes: 0 - retweets: 0
#
# page_id= doc_2318 - doc_score: 33.22426986694336 - original_tweet: We've collected many federal resources to help those affected by Hurricane Ian here: ➡ https://t.co/4sDMZhXxWR
#
#  #HurricaneIan #Ian https://t.co/xXURJpI1IW -  likes: 0 - retweets: 1
#
# page_id= doc_3172 - doc_score: 33.01578903198242 - original_tweet: Neighbors helping neighbors #hurricaneian https://t.co/Ci1dqwkCo7 -  likes: 7 - retweets: 3
#
# page_id= doc_3893 - doc_score: 32.982826232910156 - original_tweet: haven't had wifi in 2 days send help #HurricaneIan https://t.co/9nxmVq3AFA -  likes: 0 - retweets: 0
#
# page_id= doc_268 - doc_score: 32.693931579589844 - original_tweet: Our hearts are with all those affected adversely by #HurricaneIan. The Florida Disaster Fund is working to provide help and relief.
#
# Donate now: https://t.co/r9SwlqbfkD https://t.co/5wHekJ1rk6 -  likes: 11 - retweets: 6
#
# page_id= doc_3072 - doc_score: 32.66773223876953 - original_tweet: Help Reach Out America serve Florida residents impacted by Hurricane Ian.
#
# #HurricaneIan https://t.co/hWLiDex5EW -  likes: 10 - retweets: 4
#
# page_id= doc_1924 - doc_score: 32.57789993286133 - original_tweet: Best resources for anyone in Florida who needs help coping with #HurricaneIan impact: https://t.co/c4lUm7He3S and https://t.co/PSBVy8PkU0 Please stay safe. -  likes: 0 - retweets: 0

# %%
#QUERY 4:
print("flood damage:\n")
word2vec_query4 = input()
word2vec_ranking_docs4,word2vec_ranking_scores4 = word2vec_search(word2vec_query4,tweet2vec, model, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(word2vec_ranking_docs4)))
i=0
for d_id in word2vec_ranking_docs4[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} -  likes: {} - retweets: {}\n".format(d_id, word2vec_ranking_scores4[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# flood damage:
#
# flood damage
#
# ======================
# Top 20 results out of 495 for the searched query:
#
# page_id= doc_1672 - doc_score: 35.91739273071289 - original_tweet: Edgewater Florida Flooding. #HurricaneIan https://t.co/eK3lFQ0yLq -  likes: 4 - retweets: 0
#
# page_id= doc_823 - doc_score: 35.866973876953125 - original_tweet: Storm surge flooding in Myrtle Beach. #HurricaneIan https://t.co/8Pp9qUl8Vz -  likes: 5 - retweets: 2
#
# page_id= doc_3503 - doc_score: 34.873817443847656 - original_tweet: . #HurricaneIan is making its way into the Carolinas as Florida works to survey the damage.
#
# https://t.co/m3ABKeOxBG -  likes: 0 - retweets: 0
#
# page_id= doc_2782 - doc_score: 34.27949905395508 - original_tweet: Streets are starting to flood. #HurricaneIan #Charleston https://t.co/GgIvRbdlpQ -  likes: 6 - retweets: 0
#
# page_id= doc_2901 - doc_score: 33.96710968017578 - original_tweet: 9/30/2022  #HurricaneIan Florida Rain, Flood Reports
# https://t.co/fGv2hNZv1p https://t.co/vn0EcsA4oy -  likes: 0 - retweets: 0
#
# page_id= doc_1044 - doc_score: 33.862545013427734 - original_tweet: Survived the hurricane, but now we’re flooded in #HurricaneIan #Orlando https://t.co/6i0QpYp9At -  likes: 0 - retweets: 0
#
# page_id= doc_2484 - doc_score: 33.397369384765625 - original_tweet: Floods trap many in Florida as Ian heads to South Carolina
# https://t.co/zmUfHC9egM #HurricaneIan -  likes: 0 - retweets: 0
#
# page_id= doc_1324 - doc_score: 32.74528503417969 - original_tweet: Just southwest of Myrtle Beach.
#
# Storm surge flooding
#
# #HurricaneIan https://t.co/mB8wTBitp8 -  likes: 2 - retweets: 0
#
# page_id= doc_1690 - doc_score: 32.309120178222656 - original_tweet: One of the roads that we just drove down flooded with water and trees down. 😬😬 #HurricaneIan #Florida #FloridaStrong https://t.co/R2rkpdLNlF -  likes: 0 - retweets: 0
#
# page_id= doc_2091 - doc_score: 31.284656524658203 - original_tweet: Flooding downtown Charleston, SC Market Street. Follow along with us https://t.co/qAlmbaGxYK  #scwx #charleston #hurricaneian #flooding https://t.co/TXd4n2qDeO -  likes: 27 - retweets: 13
#
# page_id= doc_3508 - doc_score: 30.658761978149414 - original_tweet: If you were affected by Hurricane Ian and are seeking resources, click the link below:
#
# https://t.co/FdGPJq7yGu
#
# #hurricaneian #hurricane #fema #flooding -  likes: 0 - retweets: 0
#
# page_id= doc_2310 - doc_score: 30.642284393310547 - original_tweet: If you were affected by Hurricane Ian and are seeking resources, click the link below:
#
# https://t.co/4rj2tdO6kV
#
# #hurricaneian #hurricane #fema #flooding -  likes: 0 - retweets: 0
#
# page_id= doc_240 - doc_score: 30.5865535736084 - original_tweet: MIAMI (AP) -- #HurricaneIan makes landfall again, this time on South Carolina's coast, after causing catastrophic damage in Florida. https://t.co/4A4uqHkiJH -  likes: 0 - retweets: 0
#
# page_id= doc_353 - doc_score: 30.586278915405273 - original_tweet: MIAMI (AP) — #HurricaneIan makes landfall again, this time on South Carolina’s coast, after causing catastrophic damage in Florida https://t.co/pxfvR38kxl -  likes: 13 - retweets: 8
#
# page_id= doc_522 - doc_score: 30.418180465698242 - original_tweet: Thankfully my house is untouched by the flooding, but I can't say the same for the rest of my street...Stay safe, Central Florida!! We'll get through this 🥺
# #HurricaneIan https://t.co/8JrrbwWo6q -  likes: 2 - retweets: 0
#
# page_id= doc_1317 - doc_score: 30.37671661376953 - original_tweet: https://t.co/Tzw965uBgX
#
# Here is the SERFC's Florida briefing for flooding from #hurricaneIan #flwx #flood https://t.co/cd4ljIyNmI -  likes: 0 - retweets: 0
#
# page_id= doc_1943 - doc_score: 30.3303279876709 - original_tweet: Cooper St. Downtown Charleston, SC. You can watch live at https://t.co/qAlmbaooKC #scwx #hurricaneian #southcarolina #carolinas #flooding https://t.co/FIyk1Av5lo -  likes: 5 - retweets: 4
#
# page_id= doc_3409 - doc_score: 30.23153305053711 - original_tweet: #wellness check #HurricaneIan #Damage #venicefl https://t.co/7ZPtL5Hj8c -  likes: 2 - retweets: 1
#
# page_id= doc_3068 - doc_score: 30.22774314880371 - original_tweet: #wellness check #HurricaneIan #venicefl #damage https://t.co/8i6n8QhzEV -  likes: 0 - retweets: 0
#
# page_id= doc_1435 - doc_score: 30.066097259521484 - original_tweet: Charleston South Carolina flooded. Many of the roads around the city are impassible, and more rain expected. #hurricaneian #charleston #southcarolina #scwx https://t.co/VQNsBEfmEn -  likes: 11 - retweets: 6

# %%
#QUERY 5:
print("storm in florida:\n")
word2vec_query5 = input()
word2vec_ranking_docs5,word2vec_ranking_scores5 = word2vec_search(word2vec_query5,tweet2vec, model, index)
top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(word2vec_ranking_docs5)))
i=0
for d_id in word2vec_ranking_docs5[:top]:
    print("page_id= {} - doc_score: {} - original_tweet: {} -  likes: {} - retweets: {}\n".format(d_id, word2vec_ranking_scores5[i] ,title_index[d_id], likes[d_id], retweets[d_id]))
    i = i+1
# Out:
# storm in florida:
#
# storm in florida
#
# ======================
# Top 20 results out of 1163 for the searched query:
#
# page_id= doc_470 - doc_score: 46.780784606933594 - original_tweet: Thank God. 😢🙏🏾 #HurricaneIan
# #Florida -  likes: 1 - retweets: 0
#
# page_id= doc_3848 - doc_score: 45.888851165771484 - original_tweet: Be careful #Florida!
# #hurricaneian https://t.co/ghPKhAcjbN -  likes: 0 - retweets: 0
#
# page_id= doc_3665 - doc_score: 45.72542953491211 - original_tweet: #HurricaneIan #Florida
#
# We see.
# We vote. https://t.co/lt5PFrmNkb -  likes: 2 - retweets: 1
#
# page_id= doc_2877 - doc_score: 45.32656478881836 - original_tweet: Hurricane Ian From Cuba through Florida to South Carolina.
# #HurricaneIan https://t.co/7TypUjrtlW -  likes: 0 - retweets: 0
#
# page_id= doc_70 - doc_score: 44.28199005126953 - original_tweet: LOVE ❤️ our #Florida @GovRonDeSantis ...
#
# #HurricaneIan https://t.co/mmzGE6IZnY -  likes: 1 - retweets: 0
